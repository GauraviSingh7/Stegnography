# %%
# @title Phase 0: Environment Setup and Library Installation
# @markdown Mount Google Drive to persist data and outputs.
from google.colab import drive
drive.mount('/content/drive')

# @markdown Install all required libraries quietly.
# @markdown We include `datasets` to easily load the data from Hugging Face.
# !pip install -q pandas pyarrow torch torchvision torchaudio transformers spacy requests tqdm ftfy SPARQLWrapper datasets

# @markdown Download the SpaCy model for candidate generation.
# !python -m spacy download en_core_web_lg

# @markdown Create the project directory structure in your Google Drive.
import os

# --- IMPORTANT ---
# You can change this path to your preferred location in Google Drive
PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
# -----------------

os.makedirs(os.path.join(PROJECT_ROOT, "data"), exist_ok=True)
os.makedirs(os.path.join(PROJECT_ROOT, "notebooks"), exist_ok=True)
os.makedirs(os.path.join(PROJECT_ROOT, "output"), exist_ok=True)
os.makedirs(os.path.join(PROJECT_ROOT, "src"), exist_ok=True)

print(f"Project directory created at: {PROJECT_ROOT}")
print("Setup complete. You can now proceed with the next phases.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Collecting en-core-web-lg==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Project directory created at: /content/drive/MyDrive/ontology_project
# Setup complete. You can now proceed with the next phases.

# %%
# !unzip "/content/drive/MyDrive/ontology_project/data/cornell/cornell_movie_dialogs_corpus.zip" -d "/content/drive/MyDrive/ontology_project/data/cornell/"
# Out:
# Archive:  /content/drive/MyDrive/ontology_project/data/cornell/cornell_movie_dialogs_corpus.zip
#    creating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/.DS_Store
#    creating: /content/drive/MyDrive/ontology_project/data/cornell/__MACOSX/
#    creating: /content/drive/MyDrive/ontology_project/data/cornell/__MACOSX/cornell movie-dialogs corpus/
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/__MACOSX/cornell movie-dialogs corpus/._.DS_Store
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/chameleons.pdf
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/__MACOSX/cornell movie-dialogs corpus/._chameleons.pdf
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/movie_characters_metadata.txt
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/movie_conversations.txt
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/movie_lines.txt
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/movie_titles_metadata.txt
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/raw_script_urls.txt
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/cornell movie-dialogs corpus/README.txt
#   inflating: /content/drive/MyDrive/ontology_project/data/cornell/__MACOSX/cornell movie-dialogs corpus/._README.txt

# %%
# @title Debug: List the contents of the DailyDialog data directory
# !ls -R /content/drive/MyDrive/ontology_project/data/daily_dialog/
# Out:
# /content/drive/MyDrive/ontology_project/data/daily_dialog/:
# ijcnlp_dailydialog  ijcnlp_dailydialog.zip
#
# /content/drive/MyDrive/ontology_project/data/daily_dialog/ijcnlp_dailydialog:
# dialogues_act.txt      dialogues_text.txt   readme.txt	train.zip
# dialogues_emotion.txt  dialogues_topic.txt  test.zip	validation.zip

# %%
# @title Cell 0.1: Project Setup and Dependencies
# @markdown Run this cell once per session to set up the environment.

# --- 1. Mount Google Drive ---
from google.colab import drive
drive.mount('/content/drive')

# --- 2. Define Project Root ---
# All file paths will be relative to this root directory.
import os
PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"

# --- 3. Install All Required Packages ---
print("Installing required Python packages...")
# !pip install -q pandas pyarrow torch transformers spacy requests tqdm ftfy SPARQLWrapper

# --- 4. Download SpaCy Language Model ---
print("\nDownloading SpaCy 'en_core_web_lg' model...")
# !python -m spacy download en_core_web_lg

# --- 5. Create Project Directory Structure ---
print("\nCreating project directories...")
os.makedirs(os.path.join(PROJECT_ROOT, "data"), exist_ok=True)
os.makedirs(os.path.join(PROJECT_ROOT, "output"), exist_ok=True)
# Create subdirectories for manually downloaded data
os.makedirs(os.path.join(PROJECT_ROOT, "data/daily_dialog"), exist_ok=True)
os.makedirs(os.path.join(PROJECT_ROOT, "data/cornell"), exist_ok=True)
os.makedirs(os.path.join(PROJECT_ROOT, "data/lmsys"), exist_ok=True)


print("\nSetup complete. You may now proceed with the next cells.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Installing required Python packages...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.4/565.4 kB 21.9 MB/s eta 0:00:00
#
# Downloading SpaCy 'en_core_web_lg' model...
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
#
# Creating project directories...
#
# Setup complete. You may now proceed with the next cells.

# %%
# @title Phase 1 (Final Version): Path and ValueError Fix
import pandas as pd
import re
import os
import glob
from google.colab import drive

# --- Setup and Mounting ---
if not os.path.isdir('/content/drive/MyDrive'):
    drive.mount('/content/drive')

PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
UNIFIED_CORPUS_PATH = os.path.join(PROJECT_ROOT, "data/unified_corpus.parquet")

# --- Unzip Datasets (Run this once) ---
DAILYDIALOG_ZIP_PATH = os.path.join(PROJECT_ROOT, "data/daily_dialog/ijcnlp_dailydialog.zip")
DAILYDIALOG_EXTRACT_PATH = os.path.join(PROJECT_ROOT, "data/daily_dialog/")
if os.path.exists(DAILYDIALOG_ZIP_PATH):
    print("Unzipping main DailyDialog zip...")
    # !unzip -q -o "{DAILYDIALOG_ZIP_PATH}" -d "{DAILYDIALOG_EXTRACT_PATH}"
    NESTED_TRAIN_ZIP_PATH = os.path.join(PROJECT_ROOT, "data/daily_dialog/ijcnlp_dailydialog/train.zip")
    NESTED_EXTRACT_PATH = os.path.join(PROJECT_ROOT, "data/daily_dialog/ijcnlp_dailydialog/")
    if os.path.exists(NESTED_TRAIN_ZIP_PATH):
        print("Unzipping nested train.zip...")
        # !unzip -q -o "{NESTED_TRAIN_ZIP_PATH}" -d "{NESTED_EXTRACT_PATH}"

# --- Parsers for Manually Loaded Data ---

def clean_text(text):
    """A simple function to clean text."""
    return re.sub(r'\s+', ' ', text).strip()

def load_dailydialog():
    """Loads the DailyDialog dataset from the manually downloaded text file."""
    dialogues_path = os.path.join(PROJECT_ROOT, "data/daily_dialog/ijcnlp_dailydialog/train/dialogues_train.txt")
    if not os.path.exists(dialogues_path):
        raise FileNotFoundError(f"DailyDialog file not found at: {dialogues_path}")
    print("Loading and parsing DailyDialog dataset from text file...")
    dialogues = [line.strip().replace('__eou__', '').strip() for line in open(dialogues_path, 'r', encoding='utf-8')]
    df = pd.DataFrame({'text': dialogues, 'source_dataset': 'daily_dialog'})
    df['doc_id'] = [f"dd_{i}" for i in range(len(df))]
    return df

def load_cornell():
    """Loads the Cornell Movie Dialogs dataset from the manually uploaded files."""
    cornell_path = os.path.join(PROJECT_ROOT, "data/cornell/cornell movie-dialogs corpus")
    lines_path = os.path.join(cornell_path, 'movie_lines.txt')
    convos_path = os.path.join(cornell_path, 'movie_conversations.txt')
    if not os.path.exists(lines_path):
        raise FileNotFoundError(f"Cornell dataset files not found at: {cornell_path}")
    print("Loading and parsing Cornell Movie Dialogs dataset...")
    lines_dict = {parts[0]: parts[4] for line in open(lines_path, 'r', encoding='iso-8859-1') if len(parts := line.strip().split(' +++$+++ ')) == 5}
    dialogues = []
    for line in open(convos_path, 'r', encoding='iso-8859-1'):
        parts = line.strip().split(' +++$+++ ')
        if len(parts) == 4:
            line_ids = parts[3].replace("[", "").replace("]", "").replace("'", "").split(", ")
            full_dialogue = " ".join([lines_dict[lid] for lid in line_ids if lid in lines_dict])
            if full_dialogue:
                dialogues.append(full_dialogue)
    df = pd.DataFrame({'text': dialogues, 'source_dataset': 'cornell_movie_dialogs'})
    df['doc_id'] = [f"cornell_{i}" for i in range(len(df))]
    return df

def load_lmsys():
    """
    Loads the LMSYS-Chat-1M dataset by processing Parquet files one-by-one.
    """
    # --- FIX 1: Corrected the path to include the 'data' subdirectory ---
    lmsys_dir_path = os.path.join(PROJECT_ROOT, "data/lmsys/data/")
    if not os.path.isdir(lmsys_dir_path):
        raise FileNotFoundError(f"LMSYS data directory not found at: {lmsys_dir_path}")

    parquet_files = glob.glob(os.path.join(lmsys_dir_path, "*.parquet"))
    if not parquet_files:
        raise FileNotFoundError(f"No Parquet files found in: {lmsys_dir_path}")

    print(f"Found {len(parquet_files)} LMSYS Parquet shards. Processing one by one...")

    all_conversations = []
    for i, file_path in enumerate(parquet_files):
        print(f"  > Processing shard {i+1}/{len(parquet_files)}: {os.path.basename(file_path)}...")
        df_shard = pd.read_parquet(file_path)

        shard_conversations = []
        for conv_list in df_shard['conversation']:
            # --- FIX 2: Replaced ambiguous 'if conv_list' with explicit 'len(conv_list) > 0' ---
            if len(conv_list) > 0 and conv_list[0]['role'] == 'human':
                full_convo = " ".join([turn['content'] for turn in conv_list if turn['content']])
                shard_conversations.append(full_convo)

        all_conversations.extend(shard_conversations)

    print("Finished processing all shards.")
    df = pd.DataFrame({'text': all_conversations, 'source_dataset': 'lmsys_chat'})
    df['doc_id'] = [f"lmsys_{i}" for i in range(len(df))]
    return df

# --- Subtask 2.2: Unify and Persist Data ---

print("\nStarting data unification process...")
df_daily = load_dailydialog()
df_cornell = load_cornell()
df_lmsys = load_lmsys()
print(f"Loaded {len(df_daily)} from DailyDialog, {len(df_cornell)} from Cornell, {len(df_lmsys)} from LMSYS.")

# Balancing
min_samples = min(len(df_daily), len(df_cornell))
lmsys_sample_size = min(len(df_lmsys), min_samples * 2)
df_lmsys_sampled = df_lmsys.sample(n=lmsys_sample_size, random_state=42, replace=False)
df_cornell_sampled = df_cornell.sample(n=min_samples, random_state=42, replace=False)

# Unification
df_unified = pd.concat([df_daily, df_cornell_sampled, df_lmsys_sampled], ignore_index=True)
df_unified['text'] = df_unified['text'].apply(clean_text)
df_unified = df_unified.sample(frac=1, random_state=42).reset_index(drop=True)

df_unified.to_parquet(UNIFIED_CORPUS_PATH)

print(f"\nUnified and balanced corpus created with {len(df_unified)} documents.")
print(f"Saved to: {UNIFIED_CORPUS_PATH}")
df_unified.head()
# Out:
# Unzipping main DailyDialog zip...
# Unzipping nested train.zip...
#
# Starting data unification process...
# Loading and parsing DailyDialog dataset from text file...
# Loading and parsing Cornell Movie Dialogs dataset...
# Found 6 LMSYS Parquet shards. Processing one by one...
#   > Processing shard 1/6: train-00000-of-00006-4feeb3f83346a0e9.parquet...
#   > Processing shard 2/6: train-00001-of-00006-4030672591c2f478.parquet...
#   > Processing shard 3/6: train-00002-of-00006-1779b7cec9462180.parquet...
#   > Processing shard 4/6: train-00003-of-00006-2fa862bfed56af1f.parquet...
#   > Processing shard 5/6: train-00004-of-00006-18f4bdd50c103e71.parquet...
#   > Processing shard 6/6: train-00005-of-00006-fe1acc5d10a9f0e2.parquet...
# Finished processing all shards.
# Loaded 11118 from DailyDialog, 83079 from Cornell, 0 from LMSYS.
#
# Unified and balanced corpus created with 22236 documents.
# Saved to: /content/drive/MyDrive/ontology_project/data/unified_corpus.parquet
#                                                 text         source_dataset  \
# 0  Could I have a refund on this ? I'm afraid you...           daily_dialog
# 1  One of my students told me she was very depres...           daily_dialog
# 2  Which aisle has the produce ? Aisle A is where...           daily_dialog
# 3  Alison , would you like to have some more ? No...           daily_dialog
# 4       Well, good to see you, Miles. Jack. See you.  cornell_movie_dialogs
#
#           doc_id
# 0        dd_9960
# 1        dd_3472
# 2        dd_6842
# 3         dd_259
# 4  cornell_25340

# %%
# @title Phase 2 (Corrected): Candidate Mention Generation with SpaCy
import spacy
from tqdm.auto import tqdm
import pandas as pd
import os

# Ensure the model is downloaded in the current session.
# This is necessary if the runtime has been restarted.
#!python -m spacy download en_core_web_lg
#already done in cell 0.1

# Define paths
PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
UNIFIED_CORPUS_PATH = os.path.join(PROJECT_ROOT, "data/unified_corpus.parquet")
CANDIDATES_PATH = os.path.join(PROJECT_ROOT, "data/candidate_mentions.parquet")

# Load the SpaCy model.
nlp = spacy.load("en_core_web_lg")

def generate_candidates(texts: list[str], doc_ids: list[str]):
    """
    Extracts noun chunks as candidate mentions from a list of texts using SpaCy's nlp.pipe
    for efficient batch processing.
    """
    candidates = []

    # --- FIX APPLIED HERE ---
    # The 'parser' component is REQUIRED for the .noun_chunks attribute.
    # We remove 'parser' from the disable list. We can still disable 'ner' for performance.
    docs = nlp.pipe(texts, disable=["ner"])
    # ------------------------

    for i, doc in tqdm(enumerate(docs), total=len(texts), desc="Generating Candidates"):
        doc_id = doc_ids[i]
        for chunk in doc.noun_chunks:
            candidates.append({
                "doc_id": doc_id,
                "mention": chunk.text,
                "start_char": chunk.start_char,
                "end_char": chunk.end_char,
                "context": chunk.sent.text # E-BERT needs the sentence context
            })
    return pd.DataFrame(candidates)

# --- Usage ---
print("Loading unified corpus...")
df_unified = pd.read_parquet(UNIFIED_CORPUS_PATH)

# For demonstration, let's process a smaller subset.
# On a full run, you can remove the .head(5000)
print("Generating candidate mentions from a subset of the corpus...")
df_subset = df_unified.head(5000)
df_candidates = generate_candidates(df_subset['text'].tolist(), df_subset['doc_id'].tolist())

# Save the candidates to Parquet
df_candidates.to_parquet(CANDIDATES_PATH)

print(f"\nGenerated {len(df_candidates)} candidate mentions.")
print(f"Saved to: {CANDIDATES_PATH}")
df_candidates.head()
# Out:
# Loading unified corpus...
# Generating candidate mentions from a subset of the corpus...
# Generating Candidates:   0%|          | 0/5000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2771948188.py in <cell line: 0>()
#      50 print("Generating candidate mentions from a subset of the corpus...")
#      51 df_subset = df_unified.head(5000)
# ---> 52 df_candidates = generate_candidates(df_subset['text'].tolist(), df_subset['doc_id'].tolist())
#      53
#      54 # Save the candidates to Parquet
#
# /tmp/ipython-input-2771948188.py in generate_candidates(texts, doc_ids)
#      30     # ------------------------
#      31
# ---> 32     for i, doc in tqdm(enumerate(docs), total=len(texts), desc="Generating Candidates"):
#      33         doc_id = doc_ids[i]
#      34         for chunk in doc.noun_chunks:
#
# /usr/local/lib/python3.12/dist-packages/tqdm/notebook.py in __iter__(self)
#     248         try:
#     249             it = super().__iter__()
# --> 250             for obj in it:
#     251                 # return super(tqdm...) will not catch exception
#     252                 yield obj
#
# /usr/local/lib/python3.12/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.12/dist-packages/spacy/language.py in pipe(self, texts, as_tuples, batch_size, disable, component_cfg, n_process)
#    1620             for pipe in pipes:
#    1621                 docs = pipe(docs)
# -> 1622         for doc in docs:
#    1623             yield doc
#    1624
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1712 ) -> Iterator["Doc"]:
#    1713     if hasattr(proc, "pipe"):
# -> 1714         yield from proc.pipe(docs, **kwargs)
#    1715     else:
#    1716         # We added some args for pipe that __call__ doesn't expect.
#
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/pipe.pyx in pipe()
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1712 ) -> Iterator["Doc"]:
#    1713     if hasattr(proc, "pipe"):
# -> 1714         yield from proc.pipe(docs, **kwargs)
#    1715     else:
#    1716         # We added some args for pipe that __call__ doesn't expect.
#
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/pipe.pyx in pipe()
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1712 ) -> Iterator["Doc"]:
#    1713     if hasattr(proc, "pipe"):
# -> 1714         yield from proc.pipe(docs, **kwargs)
#    1715     else:
#    1716         # We added some args for pipe that __call__ doesn't expect.
#
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/transition_parser.pyx in pipe()
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in minibatch(items, size)
#    1659     while True:
#    1660         batch_size = next(size_)
# -> 1661         batch = list(itertools.islice(items, int(batch_size)))
#    1662         if len(batch) == 0:
#    1663             break
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1712 ) -> Iterator["Doc"]:
#    1713     if hasattr(proc, "pipe"):
# -> 1714         yield from proc.pipe(docs, **kwargs)
#    1715     else:
#    1716         # We added some args for pipe that __call__ doesn't expect.
#
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/trainable_pipe.pyx in pipe()
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in minibatch(items, size)
#    1659     while True:
#    1660         batch_size = next(size_)
# -> 1661         batch = list(itertools.islice(items, int(batch_size)))
#    1662         if len(batch) == 0:
#    1663             break
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1712 ) -> Iterator["Doc"]:
#    1713     if hasattr(proc, "pipe"):
# -> 1714         yield from proc.pipe(docs, **kwargs)
#    1715     else:
#    1716         # We added some args for pipe that __call__ doesn't expect.
#
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/trainable_pipe.pyx in pipe()
#
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/tok2vec.py in predict(self, docs)
#     119             width = self.model.get_dim("nO")
#     120             return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 121         tokvecs = self.model.predict(docs)
#     122         return tokvecs
#     123
#
# /usr/local/lib/python3.12/dist-packages/thinc/model.py in predict(self, X)
#     332         only the output, instead of the `(output, callback)` tuple.
#     333         """
# --> 334         return self._func(self, X, is_train=False)[0]
#     335
#     336     def finish_update(self, optimizer: Optimizer) -> None:
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.12/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     308         """Call the model's `forward` function, returning the output and a
#     309         callback to compute the gradients via backpropagation."""
# --> 310         return self._func(self, X, is_train=is_train)
#     311
#     312     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/with_array.py in forward(model, Xseq, is_train)
#      40         return model.layers[0](Xseq, is_train)
#      41     else:
# ---> 42         return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#      43
#      44
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/with_array.py in _list_forward(model, Xs, is_train)
#      75     lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      76     Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 77     Yf, get_dXf = layer(Xf, is_train)
#      78
#      79     def backprop(dYs: ListXd) -> ListXd:
#
# /usr/local/lib/python3.12/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     308         """Call the model's `forward` function, returning the output and a
#     309         callback to compute the gradients via backpropagation."""
# --> 310         return self._func(self, X, is_train=is_train)
#     311
#     312     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.12/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     308         """Call the model's `forward` function, returning the output and a
#     309         callback to compute the gradients via backpropagation."""
# --> 310         return self._func(self, X, is_train=is_train)
#     311
#     312     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/residual.py in forward(model, X, is_train)
#      39             return d_output + dX
#      40
# ---> 41     Y, backprop_layer = model.layers[0](X, is_train)
#      42     if isinstance(X, list):
#      43         return [X[i] + Y[i] for i in range(len(X))], backprop
#
# /usr/local/lib/python3.12/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     308         """Call the model's `forward` function, returning the output and a
#     309         callback to compute the gradients via backpropagation."""
# --> 310         return self._func(self, X, is_train=is_train)
#     311
#     312     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.12/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     308         """Call the model's `forward` function, returning the output and a
#     309         callback to compute the gradients via backpropagation."""
# --> 310         return self._func(self, X, is_train=is_train)
#     311
#     312     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.12/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     308         """Call the model's `forward` function, returning the output and a
#     309         callback to compute the gradients via backpropagation."""
# --> 310         return self._func(self, X, is_train=is_train)
#     311
#     312     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.12/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     308         """Call the model's `forward` function, returning the output and a
#     309         callback to compute the gradients via backpropagation."""
# --> 310         return self._func(self, X, is_train=is_train)
#     311
#     312     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.12/dist-packages/thinc/layers/maxout.py in forward(model, X, is_train)
#      50     W = model.get_param("W")
#      51     W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 52     Y = model.ops.gemm(X, W, trans2=True)
#      53     Y += model.ops.reshape1f(b, nO * nP)
#      54     Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
# @title Phase 3: Simulated Entity Linking
import torch
from transformers import AutoTokenizer, AutoModel
import pandas as pd
from tqdm.auto import tqdm
import numpy as np
import os

# --- This cell assumes previous phases have been run ---

PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
CANDIDATES_PATH = os.path.join(PROJECT_ROOT, "data/candidate_mentions.parquet")
LINKED_ENTITIES_PATH = os.path.join(PROJECT_ROOT, "output/linked_entities.parquet")

# --- Model Loading ---
MODEL_NAME = "bert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)

# Move model to GPU if available
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
model.eval() # Set model to evaluation mode
print(f"Model '{MODEL_NAME}' loaded on {device}.")


# --- Batch Inference Script (with Simulation) ---
def link_entities_batch_simulated(df_candidates, batch_size=32):
    """
    Processes candidates in batches and returns SIMULATED entity links.
    """
    results = []

    for i in tqdm(range(0, len(df_candidates), batch_size), desc="Linking Entities (Simulated)"):
        batch_df = df_candidates.iloc[i:i+batch_size]

        # Format inputs as required by the model: [CLS] context [SEP] mention [SEP]
        inputs = tokenizer(
            text=batch_df['context'].tolist(),
            text_pair=batch_df['mention'].tolist(),
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=128
        ).to(device)

        # Run the model
        with torch.no_grad():
            outputs = model(**inputs)
            # In a real EL model, you'd process `outputs` to get Wikidata IDs.
            # Here, we simulate this complex step.

        # --- SIMULATION LOGIC ---
        num_items = len(batch_df)
        simulated_qids = [f"Q{np.random.randint(1, 2000)}" for _ in range(num_items)]
        simulated_scores = np.random.beta(a=5, b=2, size=num_items)

        for idx, (row_index, row) in enumerate(batch_df.iterrows()):
            results.append({
                "doc_id": row['doc_id'],
                "mention": row['mention'],
                "wikidata_id": simulated_qids[idx],
                "confidence": simulated_scores[idx]
            })

    return pd.DataFrame(results)

# --- Filter Low-Confidence Links ---
print("Loading candidate mentions...")
df_candidates = pd.read_parquet(CANDIDATES_PATH)

print("Running batch linking process...")
# Using the full set of candidates generated in the previous step
df_linked_entities = link_entities_batch_simulated(df_candidates)

CONFIDENCE_THRESHOLD = 0.7
df_confident_links = df_linked_entities[df_linked_entities['confidence'] > CONFIDENCE_THRESHOLD].copy()

df_confident_links.to_parquet(LINKED_ENTITIES_PATH)

print(f"\nFinished linking. Found {len(df_linked_entities)} total links.")
print(f"Filtered to {len(df_confident_links)} confident links (confidence > {CONFIDENCE_THRESHOLD}).")
print(f"Saved to: {LINKED_ENTITIES_PATH}")
df_confident_links.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Model 'bert-base-cased' loaded on cuda.
# Loading candidate mentions...
# Running batch linking process...
# Linking Entities (Simulated):   0%|          | 0/3160 [00:00<?, ?it/s]
# Finished linking. Found 101110 total links.
# Filtered to 58769 confident links (confidence > 0.7).
# Saved to: /content/drive/MyDrive/ontology_project/output/linked_entities.parquet
#     doc_id    mention wikidata_id  confidence
# 0  dd_9960          I        Q989    0.766884
# 2  dd_9960       this       Q1226    0.829274
# 3  dd_9960          I        Q303    0.793955
# 5  dd_9960          I       Q1686    0.735059
# 7  dd_9960  something        Q348    0.810509

# %%
# @title Phase 4 (Corrected): Aggregation, Enrichment, and Ontology Building

import json
import time
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from tqdm.auto import tqdm
import os

# Define paths
PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
LINKED_ENTITIES_PATH = os.path.join(PROJECT_ROOT, "output/linked_entities.parquet")
CACHE_FILE = os.path.join(PROJECT_ROOT, "output/wikidata_cache.json")
ONTOLOGY_PATH = os.path.join(PROJECT_ROOT, "output/final_ontology.json")

# --- Subtask 5.1: Group and Aggregate by Wikidata ID ---
print("Loading confident entity links...")
df_links = pd.read_parquet(LINKED_ENTITIES_PATH)

df_aggregated = df_links.groupby('wikidata_id').agg(
    occurrences=('wikidata_id', 'count'),
    avg_confidence=('confidence', 'mean')
).reset_index().sort_values(by="occurrences", ascending=False)

print("Aggregated entity mentions:")
print(df_aggregated.head())


# --- Subtask 5.2: Wikidata Enrichment via SPARQL (with Caching) ---
def get_wikidata_details_cached(wikidata_ids: list[str]):
    """
    Queries Wikidata for details about entity IDs.
    Implements a file-based cache to avoid re-querying and respect API rate limits.
    """
    try:
        with open(CACHE_FILE, 'r') as f:
            cache = json.load(f)
    except (IOError, json.JSONDecodeError):
        cache = {}

    ids_to_fetch = [qid for qid in wikidata_ids if qid not in cache]

    if ids_to_fetch:
        print(f"Cache miss for {len(ids_to_fetch)} IDs. Querying Wikidata...")
        # Set a user-agent to be polite to the Wikidata API
        sparql = SPARQLWrapper("https://query.wikidata.org/sparql", agent="MyAwesomeOntologyProject/1.0 (myemail@example.com)")

        chunk_size = 100
        for i in tqdm(range(0, len(ids_to_fetch), chunk_size), desc="Querying Wikidata"):
            id_chunk = ids_to_fetch[i:i+chunk_size]
            query = f"""
            SELECT ?item ?itemLabel ?itemDescription (GROUP_CONCAT(DISTINCT ?type; separator=",") AS ?types)
            WHERE {{
              VALUES ?item {{wd:{' wd:'.join(id_chunk)}}}
              OPTIONAL {{ ?item wdt:P31 ?type. }}
              SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
            }}
            GROUP BY ?item ?itemLabel ?itemDescription
            """
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)

            try:
                results = sparql.query().convert()
                for result in results["results"]["bindings"]:
                    qid = result['item']['value'].split('/')[-1]
                    cache[qid] = {
                        'label': result.get('itemLabel', {}).get('value', 'N/A'),
                        'description': result.get('itemDescription', {}).get('value', 'N/A'),
                        'types': [t.split('/')[-1] for t in result.get('types', {}).get('value', '').split(',') if t]
                    }
            except Exception as e:
                print(f"Error querying Wikidata for chunk {i}: {e}")
            time.sleep(1) # Be polite to the API

        with open(CACHE_FILE, 'w') as f:
            json.dump(cache, f, indent=2)

    return {qid: cache.get(qid, {}) for qid in wikidata_ids}


# --- Subtask 5.3: Map Wikidata Types to Ontology Types ---
WIKIDATA_TYPE_MAP = {
    'Q5': 'Person', 'Q43229': 'Organization', 'Q6256': 'Country', 'Q515': 'City',
    'Q4830453': 'Business', 'Q7889': 'Movie', 'Q11424': 'Film', 'Q47461344': 'Written Work'
}

def map_entity_type(types_list):
    for qid_type in types_list:
        if qid_type in WIKIDATA_TYPE_MAP:
            return WIKIDATA_TYPE_MAP[qid_type]
    return "Other"

# --- Run Enrichment and Mapping ---
unique_ids = df_aggregated['wikidata_id'].tolist()
enriched_data = get_wikidata_details_cached(unique_ids)

df_aggregated['label'] = df_aggregated['wikidata_id'].apply(lambda qid: enriched_data.get(qid, {}).get('label', 'N/A'))
df_aggregated['description'] = df_aggregated['wikidata_id'].apply(lambda qid: enriched_data.get(qid, {}).get('description', 'N/A'))
df_aggregated['types'] = df_aggregated['wikidata_id'].apply(lambda qid: enriched_data.get(qid, {}).get('types', []))
df_aggregated['entity_type'] = df_aggregated['types'].apply(map_entity_type)

print("\nEnriched and typed data:")
print(df_aggregated.head())


# --- Task 6: Final Ontology JSON Construction ---
def build_ontology_json(df_enriched):
    """Builds the final nested JSON ontology from the enriched DataFrame."""
    ontology = {"ontology": {"id": "root", "name": "Domain", "children": []}}

    grouped_by_type = df_enriched.groupby('entity_type')

    for type_name, group_df in grouped_by_type:
        type_node = {
            "id": f"concept_{type_name.lower()}", "name": type_name,
            "description": f"Entities of type {type_name}", "children": []
        }
        for _, row in group_df.iterrows():
            entity_node = {
                "id": row['wikidata_id'], "name": row['label'], "description": row['description'],
                "metadata": {
                    "occurrences": int(row['occurrences']),
                    "avg_confidence": round(float(row['avg_confidence']), 4)
                },
                "children": []
            }
            type_node['children'].append(entity_node)
        ontology['ontology']['children'].append(type_node)

    return ontology

# --- Generate and Save the Final Ontology ---
final_ontology = build_ontology_json(df_aggregated)

with open(ONTOLOGY_PATH, 'w') as f:
    json.dump(final_ontology, f, indent=4)

print(f"\nFinal ontology constructed and saved to: {ONTOLOGY_PATH}")
print("\nOntology Snippet:")
print(json.dumps(final_ontology, indent=2)[:1000] + "...")
# Out:
# Loading confident entity links...
# Aggregated entity mentions:
#      wikidata_id  occurrences  avg_confidence
# 1540        Q586           49        0.811664
# 1859        Q873           47        0.819328
# 1254        Q328           47        0.827757
# 759        Q1682           47        0.818606
# 1251        Q325           46        0.833782
#
# Enriched and typed data:
#      wikidata_id  occurrences  avg_confidence              label  \
# 1540        Q586           49        0.811664               Bonn
# 1859        Q873           47        0.819328       Meryl Streep
# 1254        Q328           47        0.827757  English Wikipedia
# 759        Q1682           47        0.818606              Havel
# 1251        Q325           46        0.833782   digital dark age
#
#                                             description  \
# 1540  city in Germany and capital of former West Ger...
# 1859                                   American actress
# 1254              English-language edition of Wikipedia
# 759                       river in northeastern Germany
# 1251  conceptual situation in which large swathes of...
#
#                                                   types entity_type
# 1540  [Q515, Q253030, Q537250, Q1187811, Q1549591, Q...        City
# 1859                                               [Q5]      Person
# 1254                                        [Q10876391]       Other
# 759                                             [Q4022]       Other
# 1251                                           [Q41719]       Other
#
# Final ontology constructed and saved to: /content/drive/MyDrive/ontology_project/output/final_ontology.json
#
# Ontology Snippet:
# {
#   "ontology": {
#     "id": "root",
#     "name": "Domain",
#     "children": [
#       {
#         "id": "concept_business",
#         "name": "Business",
#         "description": "Entities of type Business",
#         "children": [
#           {
#             "id": "Q1902",
#             "name": "Mercedes-Benz Mobility Services",
#             "description": "German company",
#             "metadata": {
#               "occurrences": 40,
#               "avg_confidence": 0.8286
#             },
#             "children": []
#           },
#           {
#             "id": "Q1418",
#             "name": "Q1418",
#             "description": "Finnish multinational telecommunications and information technology company",
#             "metadata": {
#               "occurrences": 35,
#               "avg_confidence": 0.8478
#             },
#             "children": []
#           },
#           {
#             "id": "Q95",
#             "name": "Google",
#             "description": "American multinational technology company, a subsidiary of Alphabe...

# %% [markdown]
# ###Inorder to count number of entities
# - run the cell below
# - then cell 4
# - then final cell

# %%
# @title Phase 0: Environment Setup (Partial)
# @markdown This cell re-mounts drive and defines the project path variables.
from google.colab import drive
import os

if not os.path.isdir('/content/drive/MyDrive'):
    drive.mount('/content/drive')

PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
print(f"Project root is set to: {PROJECT_ROOT}")
# Out:
# Project root is set to: /content/drive/MyDrive/ontology_project

# %%
# @title Final Cell: Count Leaf Node Entities

# This cell assumes that the previous phase (Phase 4) has been run,
# and the following variables are available in the environment:
# - df_aggregated: The final DataFrame before JSON conversion.
# - final_ontology: The final dictionary representing the ontology.

print("--- Method 1: Counting from the final DataFrame ---")
# The number of rows in the aggregated DataFrame represents the total number
# of unique entities that should be in our final ontology.
count_from_df = len(df_aggregated)
print(f"The number of unique entities in the final DataFrame is: {count_from_df}")


print("\n--- Method 2: Counting by traversing the final JSON object ---")
# We can also count the leaf nodes by iterating through the generated structure.
# This verifies that the JSON construction process included all entities.
leaf_node_count = 0
# The first level of children are the "type" nodes (e.g., Person, Organization)
type_nodes = final_ontology.get('ontology', {}).get('children', [])

for type_node in type_nodes:
    # The children of each type_node are the entity leaf nodes
    num_entities_in_type = len(type_node.get('children', []))
    leaf_node_count += num_entities_in_type

print(f"The total number of leaf-node entities in the ontology tree is: {leaf_node_count}")


# --- Verification ---
print("\n--- Verification ---")
if count_from_df == leaf_node_count:
    print("✅ Success: The DataFrame count and the JSON tree count match.")
else:
    print("⚠️ Warning: Counts do not match. Please review the ontology construction logic.")
# Out:
# --- Method 1: Counting from the final DataFrame ---
# The number of unique entities in the final DataFrame is: 1999
#
# --- Method 2: Counting by traversing the final JSON object ---
# The total number of leaf-node entities in the ontology tree is: 1999
#
# --- Verification ---
# ✅ Success: The DataFrame count and the JSON tree count match.

# %%
# !pip install anytree
# Out:
# Collecting anytree
#   Downloading anytree-2.13.0-py3-none-any.whl.metadata (8.0 kB)
# Downloading anytree-2.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: anytree
# Successfully installed anytree-2.13.0

# %%
# @title Visualize the Full Ontology Tree
import json
from anytree import Node, RenderTree
import os

# --- This cell assumes Phase 4 has been run and the JSON file exists ---

PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
ONTOLOGY_PATH = os.path.join(PROJECT_ROOT, "output/final_ontology.json")

# 1. Load the ontology from the JSON file
try:
    with open(ONTOLOGY_PATH, 'r') as f:
        data = json.load(f)
except FileNotFoundError:
    print(f"ERROR: The ontology file was not found at {ONTOLOGY_PATH}")
    print("Please ensure you have successfully run the Phase 4 cell.")
    # Stop execution of this cell if file not found
    raise

# 2. Build the tree using anytree
root_data = data.get('ontology', {})
root_node = Node(f"{root_data.get('name', 'Root')} (id: {root_data.get('id')})")

# The first level of children are the "type" nodes (e.g., Person, Organization)
type_nodes_data = root_data.get('children', [])

for type_data in type_nodes_data:
    # Create a parent node for each entity type
    type_node = Node(f"{type_data.get('name', 'N/A')} (id: {type_data.get('id')})", parent=root_node)

    # The children of each type_node are the entity leaf nodes
    entity_nodes_data = type_data.get('children', [])
    for entity_data in entity_nodes_data:
        entity_name = entity_data.get('name', 'N/A')
        entity_id = entity_data.get('id', 'N/A')
        occurrences = entity_data.get('metadata', {}).get('occurrences', 0)

        # Create the leaf node for each entity
        Node(f"{entity_name} (id: {entity_id}, occurrences: {occurrences})", parent=type_node)

# 3. Render and print the tree
print("--- Full Ontology Tree Visualization ---")
for pre, _, node in RenderTree(root_node):
    print(f"{pre}{node.name}")
# Out:
# --- Full Ontology Tree Visualization ---
# Domain (id: root)
# ├── Business (id: concept_business)
# │   ├── Mercedes-Benz Mobility Services (id: Q1902, occurrences: 40)
# │   ├── Q1418 (id: Q1418, occurrences: 35)
# │   ├── Google (id: Q95, occurrences: 33)
# │   ├── TogliattiAzot (id: Q1343, occurrences: 32)
# │   ├── Juventus FC (id: Q1422, occurrences: 29)
# │   ├── Meta (id: Q380, occurrences: 27)
# │   └── Intel Corporation (id: Q248, occurrences: 25)
# ├── City (id: concept_city)
# │   ├── Bonn (id: Q586, occurrences: 49)
# │   ├── Jerusalem (id: Q1218, occurrences: 41)
# │   ├── Celje (id: Q1012, occurrences: 41)
# │   ├── Havana (id: Q1563, occurrences: 39)
# │   ├── Caracas (id: Q1533, occurrences: 39)
# │   ├── Wąchock (id: Q439, occurrences: 37)
# │   ├── Ho Chi Minh City (id: Q1854, occurrences: 37)
# │   ├── Kochi (id: Q1800, occurrences: 36)
# │   ├── San Marino (id: Q1848, occurrences: 35)
# │   ├── Los Angeles (id: Q65, occurrences: 35)
# │   ├── Kuala Lumpur (id: Q1865, occurrences: 35)
# │   ├── Abidjan (id: Q1515, occurrences: 35)
# │   ├── Trieste (id: Q546, occurrences: 35)
# │   ├── Abakan (id: Q875, occurrences: 35)
# │   ├── Gibraltar (id: Q1410, occurrences: 33)
# │   ├── Łódź (id: Q580, occurrences: 33)
# │   ├── Khartoum (id: Q1963, occurrences: 33)
# │   ├── Alexandria (id: Q88, occurrences: 32)
# │   ├── Juba (id: Q1947, occurrences: 32)
# │   ├── Phnom Penh (id: Q1850, occurrences: 32)
# │   ├── Milan (id: Q490, occurrences: 32)
# │   ├── Ludwigsburg (id: Q622, occurrences: 32)
# │   ├── Sharm el-Sheikh (id: Q644, occurrences: 32)
# │   ├── Wageningen (id: Q1305, occurrences: 32)
# │   ├── Bologna (id: Q1891, occurrences: 32)
# │   ├── Ljubljana (id: Q437, occurrences: 31)
# │   ├── Pune (id: Q1538, occurrences: 31)
# │   ├── Vilnius (id: Q216, occurrences: 31)
# │   ├── Mexico City (id: Q1489, occurrences: 31)
# │   ├── Reykjavík (id: Q1764, occurrences: 30)
# │   ├── Salerno (id: Q1083, occurrences: 30)
# │   ├── Nagpur (id: Q1513, occurrences: 30)
# │   ├── São Paulo (id: Q174, occurrences: 30)
# │   ├── Venice (id: Q641, occurrences: 30)
# │   ├── Bern (id: Q70, occurrences: 30)
# │   ├── Singapore (id: Q334, occurrences: 30)
# │   ├── Como (id: Q1308, occurrences: 30)
# │   ├── Bregenz (id: Q1737, occurrences: 30)
# │   ├── Bangkok (id: Q1861, occurrences: 30)
# │   ├── Luxembourg (id: Q1842, occurrences: 30)
# │   ├── Abu Dhabi (id: Q1519, occurrences: 29)
# │   ├── Alexandria (id: Q87, occurrences: 29)
# │   ├── Caserta (id: Q1906, occurrences: 29)
# │   ├── Warsaw (id: Q270, occurrences: 29)
# │   ├── Innsbruck (id: Q1735, occurrences: 29)
# │   ├── Białystok (id: Q761, occurrences: 29)
# │   ├── Schwerin (id: Q1709, occurrences: 29)
# │   ├── Appingedam (id: Q995, occurrences: 29)
# │   ├── Chelyabinsk (id: Q906, occurrences: 29)
# │   ├── Szczecin (id: Q393, occurrences: 28)
# │   ├── Koper (id: Q1015, occurrences: 28)
# │   ├── Guatemala City (id: Q1555, occurrences: 28)
# │   ├── Helsinki (id: Q1757, occurrences: 28)
# │   ├── Tashkent (id: Q269, occurrences: 28)
# │   ├── Osijek (id: Q1640, occurrences: 28)
# │   ├── Dhaka (id: Q1354, occurrences: 28)
# │   ├── Andorra la Vella (id: Q1863, occurrences: 28)
# │   ├── Taipei (id: Q1867, occurrences: 27)
# │   ├── Szczebrzeszyn (id: Q436, occurrences: 27)
# │   ├── Assen (id: Q798, occurrences: 27)
# │   ├── Dubai (id: Q612, occurrences: 27)
# │   ├── Rzeszów (id: Q598, occurrences: 27)
# │   ├── Tolyatti (id: Q1341, occurrences: 27)
# │   ├── Mumbai (id: Q1156, occurrences: 27)
# │   ├── Dar es Salaam (id: Q1960, occurrences: 27)
# │   ├── Groningen (id: Q749, occurrences: 27)
# │   ├── Gdynia (id: Q385, occurrences: 27)
# │   ├── Modena (id: Q279, occurrences: 26)
# │   ├── Barcelona (id: Q1492, occurrences: 25)
# │   ├── Copenhagen (id: Q1748, occurrences: 25)
# │   ├── London (id: Q84, occurrences: 25)
# │   ├── Toronto (id: Q172, occurrences: 25)
# │   ├── Arnhem (id: Q1310, occurrences: 25)
# │   ├── Vladivostok (id: Q959, occurrences: 24)
# │   ├── Katowice (id: Q588, occurrences: 24)
# │   ├── Cambridge (id: Q350, occurrences: 24)
# │   ├── Bratislava (id: Q1780, occurrences: 24)
# │   ├── Nowy Sącz (id: Q802, occurrences: 24)
# │   ├── Amsterdam (id: Q727, occurrences: 24)
# │   ├── Montevideo (id: Q1335, occurrences: 23)
# │   ├── Jamnagar (id: Q1154, occurrences: 22)
# │   ├── Bergamo (id: Q628, occurrences: 21)
# │   ├── Magdeburg (id: Q1733, occurrences: 21)
# │   ├── Vrhnika (id: Q438, occurrences: 20)
# │   ├── Kranj (id: Q1021, occurrences: 20)
# │   ├── Nuuk (id: Q226, occurrences: 19)
# │   ├── Stockholm (id: Q1754, occurrences: 19)
# │   └── Wolin (id: Q1862, occurrences: 9)
# ├── Country (id: concept_country)
# │   ├── Sri Lanka (id: Q854, occurrences: 43)
# │   ├── Belarus (id: Q184, occurrences: 42)
# │   ├── Turkmenistan (id: Q874, occurrences: 42)
# │   ├── The Bahamas (id: Q778, occurrences: 41)
# │   ├── Antigua and Barbuda (id: Q781, occurrences: 41)
# │   ├── Kyrgyzstan (id: Q813, occurrences: 40)
# │   ├── Guyana (id: Q734, occurrences: 39)
# │   ├── Yemen (id: Q805, occurrences: 38)
# │   ├── Algeria (id: Q262, occurrences: 38)
# │   ├── Cameroon (id: Q1009, occurrences: 37)
# │   ├── Timor-Leste (id: Q574, occurrences: 37)
# │   ├── Pakistan (id: Q843, occurrences: 37)
# │   ├── Dominican Republic (id: Q786, occurrences: 37)
# │   ├── Cuba (id: Q241, occurrences: 37)
# │   ├── Cyprus (id: Q229, occurrences: 37)
# │   ├── Cape Verde (id: Q1011, occurrences: 37)
# │   ├── Ivory Coast (id: Q1008, occurrences: 37)
# │   ├── Republic of the Congo (id: Q971, occurrences: 36)
# │   ├── Brazil (id: Q155, occurrences: 36)
# │   ├── United Arab Emirates (id: Q878, occurrences: 36)
# │   ├── Papua New Guinea (id: Q691, occurrences: 35)
# │   ├── The Gambia (id: Q1005, occurrences: 35)
# │   ├── Senegal (id: Q1041, occurrences: 35)
# │   ├── Venezuela (id: Q717, occurrences: 35)
# │   ├── Bulgaria (id: Q219, occurrences: 35)
# │   ├── Samoa (id: Q683, occurrences: 35)
# │   ├── Italy (id: Q38, occurrences: 35)
# │   ├── Austria (id: Q40, occurrences: 35)
# │   ├── Israel (id: Q801, occurrences: 35)
# │   ├── Ireland (id: Q27, occurrences: 35)
# │   ├── Portugal (id: Q45, occurrences: 34)
# │   ├── Ghana (id: Q117, occurrences: 34)
# │   ├── Laos (id: Q819, occurrences: 34)
# │   ├── Argentina (id: Q414, occurrences: 34)
# │   ├── Slovenia (id: Q215, occurrences: 34)
# │   ├── North Macedonia (id: Q221, occurrences: 34)
# │   ├── Zambia (id: Q953, occurrences: 34)
# │   ├── Uganda (id: Q1036, occurrences: 34)
# │   ├── Rwanda (id: Q1037, occurrences: 34)
# │   ├── Zimbabwe (id: Q954, occurrences: 33)
# │   ├── France (id: Q142, occurrences: 33)
# │   ├── Dominica (id: Q784, occurrences: 33)
# │   ├── Qatar (id: Q846, occurrences: 33)
# │   ├── Denmark (id: Q35, occurrences: 33)
# │   ├── Switzerland (id: Q39, occurrences: 33)
# │   ├── Lesotho (id: Q1013, occurrences: 33)
# │   ├── Norway (id: Q20, occurrences: 32)
# │   ├── Saudi Arabia (id: Q851, occurrences: 32)
# │   ├── Malta (id: Q233, occurrences: 32)
# │   ├── New Zealand (id: Q664, occurrences: 32)
# │   ├── Canada (id: Q16, occurrences: 32)
# │   ├── South Korea (id: Q884, occurrences: 32)
# │   ├── Morocco (id: Q1028, occurrences: 32)
# │   ├── Seychelles (id: Q1042, occurrences: 32)
# │   ├── Sierra Leone (id: Q1044, occurrences: 32)
# │   ├── Nicaragua (id: Q811, occurrences: 31)
# │   ├── Egypt (id: Q79, occurrences: 31)
# │   ├── Latvia (id: Q211, occurrences: 31)
# │   ├── Andorra (id: Q228, occurrences: 31)
# │   ├── Kazakhstan (id: Q232, occurrences: 31)
# │   ├── Ecuador (id: Q736, occurrences: 31)
# │   ├── Czech Republic (id: Q213, occurrences: 31)
# │   ├── Tajikistan (id: Q863, occurrences: 31)
# │   ├── Taiwan (id: Q865, occurrences: 31)
# │   ├── Djibouti (id: Q977, occurrences: 31)
# │   ├── Malaysia (id: Q833, occurrences: 30)
# │   ├── Tuvalu (id: Q672, occurrences: 30)
# │   ├── Afghanistan (id: Q889, occurrences: 30)
# │   ├── Trinidad and Tobago (id: Q754, occurrences: 30)
# │   ├── Uruguay (id: Q77, occurrences: 30)
# │   ├── Albania (id: Q222, occurrences: 30)
# │   ├── Colombia (id: Q739, occurrences: 30)
# │   ├── South Africa (id: Q258, occurrences: 30)
# │   ├── Hungary (id: Q28, occurrences: 30)
# │   ├── Tunisia (id: Q948, occurrences: 30)
# │   ├── Togo (id: Q945, occurrences: 30)
# │   ├── Greece (id: Q41, occurrences: 29)
# │   ├── Finland (id: Q33, occurrences: 29)
# │   ├── Oman (id: Q842, occurrences: 29)
# │   ├── Iran (id: Q794, occurrences: 29)
# │   ├── Iraq (id: Q796, occurrences: 29)
# │   ├── Kosovo (id: Q1246, occurrences: 29)
# │   ├── Federated States of Micronesia (id: Q702, occurrences: 29)
# │   ├── Montenegro (id: Q236, occurrences: 29)
# │   ├── Honduras (id: Q783, occurrences: 29)
# │   ├── Libya (id: Q1016, occurrences: 29)
# │   ├── Mexico (id: Q96, occurrences: 29)
# │   ├── Bhutan (id: Q917, occurrences: 29)
# │   ├── El Salvador (id: Q792, occurrences: 28)
# │   ├── Paraguay (id: Q733, occurrences: 28)
# │   ├── Bolivia (id: Q750, occurrences: 28)
# │   ├── Maldives (id: Q826, occurrences: 28)
# │   ├── Kenya (id: Q114, occurrences: 28)
# │   ├── Myanmar (id: Q836, occurrences: 28)
# │   ├── United States (id: Q30, occurrences: 28)
# │   ├── Costa Rica (id: Q800, occurrences: 28)
# │   ├── Uzbekistan (id: Q265, occurrences: 28)
# │   ├── Palau (id: Q695, occurrences: 28)
# │   ├── Spain (id: Q29, occurrences: 28)
# │   ├── Cambodia (id: Q424, occurrences: 28)
# │   ├── Vietnam (id: Q881, occurrences: 28)
# │   ├── Benin (id: Q962, occurrences: 27)
# │   ├── South Sudan (id: Q958, occurrences: 27)
# │   ├── Eritrea (id: Q986, occurrences: 27)
# │   ├── Ethiopia (id: Q115, occurrences: 27)
# │   ├── Jordan (id: Q810, occurrences: 27)
# │   ├── Luxembourg (id: Q32, occurrences: 27)
# │   ├── Sweden (id: Q34, occurrences: 27)
# │   ├── Saint Vincent and the Grenadines (id: Q757, occurrences: 27)
# │   ├── Bosnia and Herzegovina (id: Q225, occurrences: 27)
# │   ├── Vatican City (id: Q237, occurrences: 27)
# │   ├── Nauru (id: Q697, occurrences: 27)
# │   ├── Mauritania (id: Q1025, occurrences: 27)
# │   ├── Niger (id: Q1032, occurrences: 27)
# │   ├── Lithuania (id: Q37, occurrences: 27)
# │   ├── Angola (id: Q916, occurrences: 27)
# │   ├── Malawi (id: Q1020, occurrences: 27)
# │   ├── Sudan (id: Q1049, occurrences: 26)
# │   ├── Mauritius (id: Q1027, occurrences: 26)
# │   ├── Burundi (id: Q967, occurrences: 26)
# │   ├── Syria (id: Q858, occurrences: 26)
# │   ├── Gabon (id: Q1000, occurrences: 26)
# │   ├── Germany (id: Q183, occurrences: 26)
# │   ├── Mongolia (id: Q711, occurrences: 26)
# │   ├── Croatia (id: Q224, occurrences: 26)
# │   ├── Comoros (id: Q970, occurrences: 25)
# │   ├── Brunei (id: Q921, occurrences: 25)
# │   ├── Burkina Faso (id: Q965, occurrences: 25)
# │   ├── Liberia (id: Q1014, occurrences: 25)
# │   ├── Bahrain (id: Q398, occurrences: 25)
# │   ├── People's Republic of China (id: Q148, occurrences: 25)
# │   ├── Vanuatu (id: Q686, occurrences: 25)
# │   ├── Netherlands (id: Q55, occurrences: 25)
# │   ├── Russia (id: Q159, occurrences: 25)
# │   ├── Chad (id: Q657, occurrences: 25)
# │   ├── Philippines (id: Q928, occurrences: 24)
# │   ├── Australia (id: Q408, occurrences: 24)
# │   ├── Jamaica (id: Q766, occurrences: 24)
# │   ├── Lebanon (id: Q822, occurrences: 24)
# │   ├── Mali (id: Q912, occurrences: 24)
# │   ├── Azerbaijan (id: Q227, occurrences: 24)
# │   ├── Liechtenstein (id: Q347, occurrences: 24)
# │   ├── Solomon Islands (id: Q685, occurrences: 24)
# │   ├── Democratic Republic of the Congo (id: Q974, occurrences: 24)
# │   ├── Fiji (id: Q712, occurrences: 24)
# │   ├── Saint Lucia (id: Q760, occurrences: 24)
# │   ├── Namibia (id: Q1030, occurrences: 23)
# │   ├── Somalia (id: Q1045, occurrences: 23)
# │   ├── Belgium (id: Q31, occurrences: 23)
# │   ├── Armenia (id: Q399, occurrences: 23)
# │   ├── Thailand (id: Q869, occurrences: 23)
# │   ├── Nepal (id: Q837, occurrences: 23)
# │   ├── Indonesia (id: Q252, occurrences: 23)
# │   ├── Estonia (id: Q191, occurrences: 23)
# │   ├── Chile (id: Q298, occurrences: 23)
# │   ├── Saint Kitts and Nevis (id: Q763, occurrences: 23)
# │   ├── Romania (id: Q218, occurrences: 23)
# │   ├── Tanzania (id: Q924, occurrences: 22)
# │   ├── Iceland (id: Q189, occurrences: 22)
# │   ├── Botswana (id: Q963, occurrences: 22)
# │   ├── United Kingdom (id: Q145, occurrences: 22)
# │   ├── Japan (id: Q17, occurrences: 21)
# │   ├── São Tomé and Príncipe (id: Q1039, occurrences: 21)
# │   ├── Guatemala (id: Q774, occurrences: 21)
# │   ├── Grenada (id: Q769, occurrences: 21)
# │   ├── North Korea (id: Q423, occurrences: 21)
# │   ├── Turkey (id: Q43, occurrences: 20)
# │   ├── Guinea (id: Q1006, occurrences: 20)
# │   ├── Bangladesh (id: Q902, occurrences: 20)
# │   ├── Nigeria (id: Q1033, occurrences: 19)
# │   ├── Poland (id: Q36, occurrences: 19)
# │   ├── Central African Republic (id: Q929, occurrences: 19)
# │   ├── India (id: Q668, occurrences: 17)
# │   └── Slovakia (id: Q214, occurrences: 15)
# ├── Film (id: concept_film)
# │   ├── Swept Away (id: Q1365, occurrences: 35)
# │   ├── A Gang Story (id: Q593, occurrences: 34)
# │   ├── The Intouchables (id: Q595, occurrences: 26)
# │   └── We Live in Public (id: Q372, occurrences: 26)
# ├── Organization (id: concept_organization)
# │   ├── Boeing (id: Q66, occurrences: 38)
# │   ├── Solidarity (id: Q1003, occurrences: 34)
# │   ├── University of Ljubljana (id: Q1377, occurrences: 33)
# │   ├── Apple Inc. (id: Q312, occurrences: 22)
# │   └── Airbus (id: Q67, occurrences: 21)
# ├── Other (id: concept_other)
# │   ├── English Wikipedia (id: Q328, occurrences: 47)
# │   ├── Havel (id: Q1682, occurrences: 47)
# │   ├── digital dark age (id: Q325, occurrences: 46)
# │   ├── Dresden (id: Q1731, occurrences: 45)
# │   ├── Padua (id: Q617, occurrences: 45)
# │   ├── St. Pauli (id: Q1556, occurrences: 44)
# │   ├── La Paz (id: Q1491, occurrences: 44)
# │   ├── Nagaland (id: Q1599, occurrences: 44)
# │   ├── Q364 (id: Q364, occurrences: 43)
# │   ├── livermorium (id: Q1304, occurrences: 43)
# │   ├── Veneto (id: Q1243, occurrences: 43)
# │   ├── Elde (id: Q1688, occurrences: 43)
# │   ├── Nienstedten (id: Q1601, occurrences: 43)
# │   ├── Eimsbüttel (id: Q1611, occurrences: 43)
# │   ├── Sun (id: Q525, occurrences: 43)
# │   ├── star (id: Q523, occurrences: 43)
# │   ├── Q417 (id: Q417, occurrences: 42)
# │   ├── 2002 (id: Q1987, occurrences: 42)
# │   ├── copper (id: Q753, occurrences: 42)
# │   ├── Mount Everest (id: Q513, occurrences: 42)
# │   ├── Sagas of Icelanders (id: Q300, occurrences: 42)
# │   ├── Mars (id: Q112, occurrences: 42)
# │   ├── Cervelle de canut (id: Q554, occurrences: 42)
# │   ├── Fontgombault Abbey (id: Q591, occurrences: 42)
# │   ├── Bordeaux (id: Q1479, occurrences: 42)
# │   ├── Cairo (id: Q85, occurrences: 42)
# │   ├── avenue des Champs-Élysées (id: Q550, occurrences: 42)
# │   ├── Q789 (id: Q789, occurrences: 42)
# │   ├── Fuhlsbüttel (id: Q1163, occurrences: 42)
# │   ├── Q840 (id: Q840, occurrences: 41)
# │   ├── Insular Oceania (id: Q538, occurrences: 41)
# │   ├── actinium (id: Q1121, occurrences: 41)
# │   ├── car (id: Q1420, occurrences: 41)
# │   ├── Alps (id: Q1286, occurrences: 41)
# │   ├── pig (id: Q787, occurrences: 41)
# │   ├── Q63 (id: Q63, occurrences: 41)
# │   ├── Jharkhand (id: Q1184, occurrences: 40)
# │   ├── Groß Flottbek (id: Q1606, occurrences: 40)
# │   ├── Düren (id: Q1884, occurrences: 40)
# │   ├── queen (id: Q139, occurrences: 40)
# │   ├── train (id: Q870, occurrences: 40)
# │   ├── Ottawa (id: Q1930, occurrences: 40)
# │   ├── praseodymium (id: Q1386, occurrences: 40)
# │   ├── Iténez (id: Q823, occurrences: 40)
# │   ├── smile (id: Q487, occurrences: 40)
# │   ├── Derval (id: Q478, occurrences: 40)
# │   ├── Council of Lyon (id: Q630, occurrences: 40)
# │   ├── dictatorship (id: Q317, occurrences: 40)
# │   ├── San Francisco (id: Q62, occurrences: 40)
# │   ├── Düsseldorf (id: Q1718, occurrences: 40)
# │   ├── Iserbrook (id: Q1605, occurrences: 40)
# │   ├── Tours (id: Q288, occurrences: 40)
# │   ├── cognac (id: Q284, occurrences: 40)
# │   ├── hassium (id: Q1252, occurrences: 40)
# │   ├── Urdu (id: Q1617, occurrences: 40)
# │   ├── Tuscany (id: Q1273, occurrences: 40)
# │   ├── Q637 (id: Q637, occurrences: 40)
# │   ├── X-ray astronomy (id: Q1852, occurrences: 40)
# │   ├── lemonade (id: Q893, occurrences: 40)
# │   ├── athletics (id: Q542, occurrences: 40)
# │   ├── Alexander (id: Q923, occurrences: 40)
# │   ├── Togliatti surface (id: Q1847, occurrences: 40)
# │   ├── Top Gear (id: Q910, occurrences: 39)
# │   ├── Skagerrak (id: Q1695, occurrences: 39)
# │   ├── July (id: Q121, occurrences: 39)
# │   ├── evolution (id: Q1063, occurrences: 39)
# │   ├── organ (id: Q1444, occurrences: 39)
# │   ├── Drosera (id: Q266, occurrences: 39)
# │   ├── Apulia (id: Q1447, occurrences: 39)
# │   ├── Texas (id: Q1439, occurrences: 39)
# │   ├── curium (id: Q1876, occurrences: 39)
# │   ├── Q9 (id: Q9, occurrences: 39)
# │   ├── Rissen (id: Q1596, occurrences: 39)
# │   ├── Bastille (id: Q689, occurrences: 39)
# │   ├── 2011 (id: Q1994, occurrences: 39)
# │   ├── Mary (id: Q345, occurrences: 39)
# │   ├── Elbe (id: Q1644, occurrences: 39)
# │   ├── Death Note (id: Q1834, occurrences: 39)
# │   ├── Solar System (id: Q544, occurrences: 39)
# │   ├── Life, the Universe and Everything (id: Q721, occurrences: 39)
# │   ├── nihonium (id: Q1301, occurrences: 39)
# │   ├── corruption (id: Q366, occurrences: 39)
# │   ├── Nebraska (id: Q1553, occurrences: 39)
# │   ├── Q382 (id: Q382, occurrences: 39)
# │   ├── Monsols (id: Q1964, occurrences: 39)
# │   ├── astatine (id: Q999, occurrences: 39)
# │   ├── Q92 (id: Q92, occurrences: 39)
# │   ├── Museum of Fine Arts of Lyon (id: Q511, occurrences: 39)
# │   ├── Catania (id: Q1903, occurrences: 39)
# │   ├── Gdańsk (id: Q1792, occurrences: 39)
# │   ├── Province of Namur (id: Q1125, occurrences: 39)
# │   ├── Altona (id: Q1630, occurrences: 39)
# │   ├── wine (id: Q282, occurrences: 39)
# │   ├── Lugdunum Musée et Théâtres (id: Q509, occurrences: 39)
# │   ├── lead (id: Q708, occurrences: 39)
# │   ├── immune system (id: Q1059, occurrences: 38)
# │   ├── Lopadotemachoselachogaleokranioleipsanodrimhypotrimmatosilphiokarabomelitokatakechymenokichlepikossyphophattoperisteralektryonoptekephalliokigklopeleiolagoiosiraiobaphetraganopterygon (id: Q101, occurrences: 38)
# │   ├── Basel (id: Q78, occurrences: 38)
# │   ├── Maharashtra (id: Q1191, occurrences: 38)
# │   ├── Münsterland (id: Q1700, occurrences: 38)
# │   ├── Wikibooks (id: Q367, occurrences: 38)
# │   ├── Panama (id: Q804, occurrences: 38)
# │   ├── Wikimedia Commons (id: Q565, occurrences: 38)
# │   ├── swimming pool (id: Q1501, occurrences: 38)
# │   ├── Ich bin ein Berliner (id: Q443, occurrences: 38)
# │   ├── Oregon (id: Q824, occurrences: 38)
# │   ├── xenon (id: Q1106, occurrences: 38)
# │   ├── More Than Life at Stake (id: Q961, occurrences: 38)
# │   ├── krypton (id: Q888, occurrences: 38)
# │   ├── Cafeteria (id: Q267, occurrences: 38)
# │   ├── computer virus (id: Q485, occurrences: 38)
# │   ├── Kaliningrad Oblast (id: Q1749, occurrences: 38)
# │   ├── Q304 (id: Q304, occurrences: 38)
# │   ├── North Dakota (id: Q1207, occurrences: 38)
# │   ├── Rhônexpress (id: Q1559, occurrences: 38)
# │   ├── Istanbul (id: Q406, occurrences: 37)
# │   ├── Plovdiv (id: Q459, occurrences: 37)
# │   ├── headache (id: Q86, occurrences: 37)
# │   ├── purgatory (id: Q566, occurrences: 37)
# │   ├── Ahlen (id: Q1132, occurrences: 37)
# │   ├── New Brunswick (id: Q1965, occurrences: 37)
# │   ├── Oslo (id: Q585, occurrences: 37)
# │   ├── Iowa (id: Q1546, occurrences: 37)
# │   ├── knight (id: Q136, occurrences: 37)
# │   ├── West Virginia (id: Q1371, occurrences: 37)
# │   ├── Arachnida (id: Q1358, occurrences: 37)
# │   ├── Pirate Parties International (id: Q170, occurrences: 37)
# │   ├── north (id: Q659, occurrences: 37)
# │   ├── funeral litre (id: Q314, occurrences: 37)
# │   ├── monarch (id: Q116, occurrences: 37)
# │   ├── traffic circle (id: Q1529, occurrences: 37)
# │   ├── carrot (id: Q81, occurrences: 37)
# │   ├── Arunachal Pradesh (id: Q1162, occurrences: 37)
# │   ├── Inter Milan (id: Q631, occurrences: 37)
# │   ├── Q1334 (id: Q1334, occurrences: 37)
# │   ├── Q201 (id: Q201, occurrences: 37)
# │   ├── Category:Contents (id: Q1281, occurrences: 37)
# │   ├── triskaidekaphobia (id: Q13, occurrences: 37)
# │   ├── South Holland (id: Q694, occurrences: 37)
# │   ├── Flanders (id: Q234, occurrences: 37)
# │   ├── rutherfordium (id: Q1226, occurrences: 37)
# │   ├── computer keyboard (id: Q250, occurrences: 37)
# │   ├── Eurovision Song Contest (id: Q276, occurrences: 37)
# │   ├── United Nations (id: Q1065, occurrences: 37)
# │   ├── Odesa (id: Q1874, occurrences: 37)
# │   ├── palladium (id: Q1089, occurrences: 36)
# │   ├── Felsberg (id: Q1481, occurrences: 36)
# │   ├── Dyson sphere (id: Q469, occurrences: 36)
# │   ├── Mississippi (id: Q1494, occurrences: 36)
# │   ├── Q479 (id: Q479, occurrences: 36)
# │   ├── fairy tale (id: Q699, occurrences: 36)
# │   ├── Kamchatka Peninsula (id: Q993, occurrences: 36)
# │   ├── Finnish (id: Q1412, occurrences: 36)
# │   ├── Split (id: Q1663, occurrences: 36)
# │   ├── ununennium (id: Q1139, occurrences: 36)
# │   ├── biology (id: Q420, occurrences: 36)
# │   ├── Chihuahua (id: Q653, occurrences: 36)
# │   ├── Opel Astra (id: Q1350, occurrences: 36)
# │   ├── Italian (id: Q652, occurrences: 36)
# │   ├── Othmarschen (id: Q1598, occurrences: 36)
# │   ├── Apennines (id: Q1285, occurrences: 36)
# │   ├── aluminium (id: Q663, occurrences: 36)
# │   ├── Sülldorf (id: Q1593, occurrences: 36)
# │   ├── cobalt (id: Q740, occurrences: 36)
# │   ├── Missouri (id: Q1581, occurrences: 36)
# │   ├── wood (id: Q287, occurrences: 36)
# │   ├── Liguria (id: Q1256, occurrences: 36)
# │   ├── Alaska (id: Q797, occurrences: 36)
# │   ├── Mercury (id: Q1150, occurrences: 36)
# │   ├── censorship (id: Q543, occurrences: 36)
# │   ├── The King of Rome (id: Q594, occurrences: 36)
# │   ├── Rhode Island (id: Q1387, occurrences: 36)
# │   ├── tellurium (id: Q1100, occurrences: 36)
# │   ├── South America (id: Q18, occurrences: 36)
# │   ├── Linkin Park (id: Q261, occurrences: 36)
# │   ├── holmium (id: Q1846, occurrences: 36)
# │   ├── skin (id: Q1074, occurrences: 36)
# │   ├── Odenas (id: Q1982, occurrences: 36)
# │   ├── Tanauan (id: Q1730, occurrences: 36)
# │   ├── Earth (id: Q2, occurrences: 36)
# │   ├── Langenhorn (id: Q1175, occurrences: 36)
# │   ├── rectangle (id: Q209, occurrences: 36)
# │   ├── 2009 (id: Q1996, occurrences: 36)
# │   ├── printer (id: Q82, occurrences: 36)
# │   ├── Vienna (id: Q1741, occurrences: 36)
# │   ├── Wikiversity (id: Q370, occurrences: 36)
# │   ├── Q620 (id: Q620, occurrences: 36)
# │   ├── Utrecht (id: Q803, occurrences: 36)
# │   ├── Hurricane Sandy (id: Q264, occurrences: 35)
# │   ├── Quezon City (id: Q1475, occurrences: 35)
# │   ├── zirconium (id: Q1038, occurrences: 35)
# │   ├── lutetium (id: Q1857, occurrences: 35)
# │   ├── unbiunium (id: Q1466, occurrences: 35)
# │   ├── hacker (id: Q1487, occurrences: 35)
# │   ├── bismuth (id: Q942, occurrences: 35)
# │   ├── Q1864 (id: Q1864, occurrences: 35)
# │   ├── uranium (id: Q1098, occurrences: 35)
# │   ├── rainbow (id: Q1052, occurrences: 35)
# │   ├── Arthropoda (id: Q1360, occurrences: 35)
# │   ├── infant (id: Q998, occurrences: 35)
# │   ├── number of the beast (id: Q666, occurrences: 35)
# │   ├── equinox (id: Q1315, occurrences: 35)
# │   ├── Valenzuela (id: Q1623, occurrences: 35)
# │   ├── fish (id: Q152, occurrences: 35)
# │   ├── Gelderland (id: Q775, occurrences: 35)
# │   ├── Hawaii (id: Q782, occurrences: 35)
# │   ├── Spanish (id: Q1321, occurrences: 35)
# │   ├── Mecklenburg-Vorpommern (id: Q1196, occurrences: 35)
# │   ├── Lamitan (id: Q1714, occurrences: 35)
# │   ├── Saarbrücken (id: Q1724, occurrences: 35)
# │   ├── Dubrovnik (id: Q1722, occurrences: 35)
# │   ├── Q1995 (id: Q1995, occurrences: 35)
# │   ├── Canton of Valais (id: Q834, occurrences: 35)
# │   ├── Chihuahua (id: Q655, occurrences: 35)
# │   ├── cherry (id: Q196, occurrences: 35)
# │   ├── Cercado (id: Q821, occurrences: 35)
# │   ├── vanadium (id: Q722, occurrences: 35)
# │   ├── August (id: Q122, occurrences: 35)
# │   ├── Neckar (id: Q1673, occurrences: 35)
# │   ├── leather (id: Q286, occurrences: 35)
# │   ├── Wednesday (id: Q128, occurrences: 35)
# │   ├── Llanfairpwllgwyngyll (id: Q322, occurrences: 35)
# │   ├── magnesium (id: Q660, occurrences: 35)
# │   ├── Iglesia (id: Q1594, occurrences: 35)
# │   ├── Rome (id: Q220, occurrences: 35)
# │   ├── blue (id: Q1088, occurrences: 35)
# │   ├── Lake Ontario (id: Q1062, occurrences: 35)
# │   ├── death (id: Q4, occurrences: 35)
# │   ├── Q199 (id: Q199, occurrences: 35)
# │   ├── Billstedt (id: Q1565, occurrences: 35)
# │   ├── Końskowola (id: Q1959, occurrences: 35)
# │   ├── Warburg (id: Q968, occurrences: 35)
# │   ├── 666 (id: Q505, occurrences: 35)
# │   ├── Tamil Nadu (id: Q1445, occurrences: 35)
# │   ├── house cat (id: Q146, occurrences: 35)
# │   ├── polonium (id: Q979, occurrences: 35)
# │   ├── Sikkim (id: Q1505, occurrences: 35)
# │   ├── Gmina Kurów (id: Q433, occurrences: 35)
# │   ├── insect (id: Q1390, occurrences: 35)
# │   ├── Peene (id: Q1658, occurrences: 35)
# │   ├── Africa (id: Q15, occurrences: 35)
# │   ├── Piran (id: Q1382, occurrences: 35)
# │   ├── Ufa (id: Q911, occurrences: 35)
# │   ├── World Brain (id: Q470, occurrences: 35)
# │   ├── foobar (id: Q860, occurrences: 35)
# │   ├── Rahlstedt (id: Q1820, occurrences: 34)
# │   ├── Q850 (id: Q850, occurrences: 34)
# │   ├── Tennessee (id: Q1509, occurrences: 34)
# │   ├── century (id: Q578, occurrences: 34)
# │   ├── penis (id: Q58, occurrences: 34)
# │   ├── zoology (id: Q431, occurrences: 34)
# │   ├── woman (id: Q467, occurrences: 34)
# │   ├── Bible (id: Q1845, occurrences: 34)
# │   ├── Mandelbrot set (id: Q257, occurrences: 34)
# │   ├── anatomy (id: Q514, occurrences: 34)
# │   ├── long-eared hedgehog (id: Q1459, occurrences: 34)
# │   ├── South Carolina (id: Q1456, occurrences: 34)
# │   ├── Arkhangelsk Oblast (id: Q1875, occurrences: 34)
# │   ├── Suez Canal (id: Q899, occurrences: 34)
# │   ├── Funiculars of Lyon (id: Q1550, occurrences: 34)
# │   ├── Linux (id: Q388, occurrences: 34)
# │   ├── Chhattisgarh (id: Q1168, occurrences: 34)
# │   ├── chocolate (id: Q195, occurrences: 34)
# │   ├── Alabama (id: Q173, occurrences: 34)
# │   ├── alcoholic beverage (id: Q154, occurrences: 34)
# │   ├── Cemetery of Croix-Rousse (id: Q1542, occurrences: 34)
# │   ├── Grande synagogue de Lyon (id: Q1531, occurrences: 34)
# │   ├── Bron (id: Q1291, occurrences: 34)
# │   ├── Internet Explorer (id: Q1575, occurrences: 34)
# │   ├── Rothenburgsort (id: Q1580, occurrences: 34)
# │   ├── music (id: Q638, occurrences: 34)
# │   ├── Karnataka (id: Q1185, occurrences: 34)
# │   ├── Aquitaine (id: Q1179, occurrences: 34)
# │   ├── Hoheluft-Ost (id: Q1181, occurrences: 34)
# │   ├── World War III (id: Q363, occurrences: 34)
# │   ├── Q202 (id: Q202, occurrences: 34)
# │   ├── Isabela (id: Q1710, occurrences: 34)
# │   ├── North Rhine-Westphalia (id: Q1198, occurrences: 34)
# │   ├── Q355 (id: Q355, occurrences: 34)
# │   ├── future (id: Q344, occurrences: 34)
# │   ├── 2013 (id: Q1998, occurrences: 34)
# │   ├── tennis (id: Q847, occurrences: 34)
# │   ├── Schulze method (id: Q113, occurrences: 34)
# │   ├── Saturn (id: Q193, occurrences: 34)
# │   ├── Ceres (id: Q596, occurrences: 34)
# │   ├── Bengaluru (id: Q1355, occurrences: 34)
# │   ├── West Bengal (id: Q1356, occurrences: 34)
# │   ├── sodium (id: Q658, occurrences: 34)
# │   ├── Ottensen (id: Q1597, occurrences: 34)
# │   ├── Osdorf (id: Q1600, occurrences: 34)
# │   ├── free software (id: Q341, occurrences: 34)
# │   ├── Sunday (id: Q132, occurrences: 34)
# │   ├── oganesson (id: Q1307, occurrences: 34)
# │   ├── Wikisource (id: Q263, occurrences: 34)
# │   ├── Kiribati (id: Q710, occurrences: 34)
# │   ├── South Dakota (id: Q1211, occurrences: 34)
# │   ├── Fragaria (id: Q745, occurrences: 34)
# │   ├── art (id: Q735, occurrences: 34)
# │   ├── Belize (id: Q242, occurrences: 34)
# │   ├── Eiffel Tower (id: Q243, occurrences: 34)
# │   ├── November (id: Q125, occurrences: 34)
# │   ├── Cottian Alps (id: Q1251, occurrences: 34)
# │   ├── Marshall Islands (id: Q709, occurrences: 34)
# │   ├── Cagayan de Oro (id: Q1645, occurrences: 34)
# │   ├── Boston (id: Q100, occurrences: 34)
# │   ├── Steilshoop (id: Q1824, occurrences: 34)
# │   ├── Shit (id: Q519, occurrences: 34)
# │   ├── Naruto Uzumaki (id: Q931, occurrences: 34)
# │   ├── Q477 (id: Q477, occurrences: 34)
# │   ├── Tokyo (id: Q1490, occurrences: 34)
# │   ├── Hemer (id: Q1104, occurrences: 34)
# │   ├── March (id: Q110, occurrences: 34)
# │   ├── Ahmedabad (id: Q1070, occurrences: 34)
# │   ├── Arkhangelsk (id: Q1851, occurrences: 33)
# │   ├── narcotic (id: Q940, occurrences: 33)
# │   ├── Betta edithae (id: Q518, occurrences: 33)
# │   ├── Caloocan (id: Q1478, occurrences: 33)
# │   ├── Ñ (id: Q476, occurrences: 33)
# │   ├── Nyan Cat (id: Q149, occurrences: 33)
# │   ├── indium (id: Q1094, occurrences: 33)
# │   ├── neptunium (id: Q1105, occurrences: 33)
# │   ├── Busto Arsizio (id: Q1155, occurrences: 33)
# │   ├── Uetersen (id: Q1404, occurrences: 33)
# │   ├── Himachal Pradesh (id: Q1177, occurrences: 33)
# │   ├── Haryana (id: Q1174, occurrences: 33)
# │   ├── Burgundy (id: Q1173, occurrences: 33)
# │   ├── Oder (id: Q552, occurrences: 33)
# │   ├── europium (id: Q1396, occurrences: 33)
# │   ├── Winterhude (id: Q1148, occurrences: 33)
# │   ├── human (id: Q5, occurrences: 33)
# │   ├── Q1431 (id: Q1431, occurrences: 33)
# │   ├── Beakman's World (id: Q494, occurrences: 33)
# │   ├── Haiti (id: Q790, occurrences: 33)
# │   ├── Q1144 (id: Q1144, occurrences: 33)
# │   ├── Ternand (id: Q1969, occurrences: 33)
# │   ├── All Saints' Day (id: Q587, occurrences: 33)
# │   ├── Bleach (id: Q904, occurrences: 33)
# │   ├── Diplomacy (id: Q1871, occurrences: 33)
# │   ├── samarium (id: Q1819, occurrences: 33)
# │   ├── Colorado River (id: Q1265, occurrences: 33)
# │   ├── geology (id: Q1069, occurrences: 33)
# │   ├── galaxy (id: Q318, occurrences: 33)
# │   ├── moscovium (id: Q1303, occurrences: 33)
# │   ├── Google+ (id: Q356, occurrences: 33)
# │   ├── summer (id: Q1313, occurrences: 33)
# │   ├── Hamburg-Nord (id: Q1627, occurrences: 33)
# │   ├── water (id: Q283, occurrences: 33)
# │   ├── bohrium (id: Q1249, occurrences: 33)
# │   ├── Q292 (id: Q292, occurrences: 33)
# │   ├── Volga (id: Q626, occurrences: 33)
# │   ├── Montana (id: Q1212, occurrences: 33)
# │   ├── animal (id: Q729, occurrences: 33)
# │   ├── Idaho (id: Q1221, occurrences: 33)
# │   ├── Billbrook (id: Q1567, occurrences: 33)
# │   ├── City of Brussels (id: Q239, occurrences: 33)
# │   ├── Q1369 (id: Q1369, occurrences: 33)
# │   ├── citation (id: Q1713, occurrences: 33)
# │   ├── Schleswig-Holstein (id: Q1194, occurrences: 33)
# │   ├── 136472 Makemake (id: Q604, occurrences: 33)
# │   ├── U2 (id: Q396, occurrences: 33)
# │   ├── Ubuntu (id: Q381, occurrences: 33)
# │   ├── prose (id: Q676, occurrences: 33)
# │   ├── sulfur (id: Q682, occurrences: 33)
# │   ├── jam (id: Q1269, occurrences: 33)
# │   ├── banana (id: Q503, occurrences: 33)
# │   ├── acqua alta (id: Q1873, occurrences: 33)
# │   ├── California (id: Q99, occurrences: 33)
# │   ├── Star Trek: The Original Series (id: Q1077, occurrences: 33)
# │   ├── Q47 (id: Q47, occurrences: 32)
# │   ├── Q572 (id: Q572, occurrences: 32)
# │   ├── infinity (id: Q205, occurrences: 32)
# │   ├── Hôtel de Ville de Lyon (id: Q516, occurrences: 32)
# │   ├── Novosibirsk (id: Q883, occurrences: 32)
# │   ├── bromine (id: Q879, occurrences: 32)
# │   ├── Seine (id: Q1471, occurrences: 32)
# │   ├── Esperanto (id: Q143, occurrences: 32)
# │   ├── radium (id: Q1128, occurrences: 32)
# │   ├── Dulsberg (id: Q1141, occurrences: 32)
# │   ├── comics (id: Q1004, occurrences: 32)
# │   ├── North Pole (id: Q934, occurrences: 32)
# │   ├── Bangka Belitung Islands (id: Q1866, occurrences: 32)
# │   ├── Schnütgen Museum (id: Q950, occurrences: 32)
# │   ├── yellow (id: Q943, occurrences: 32)
# │   ├── lion (id: Q140, occurrences: 32)
# │   ├── unbinilium (id: Q1146, occurrences: 32)
# │   ├── Uhlenhorst (id: Q1143, occurrences: 32)
# │   ├── Givors (id: Q1976, occurrences: 32)
# │   ├── silbo Gomero (id: Q415, occurrences: 32)
# │   ├── Lyon (id: Q456, occurrences: 32)
# │   ├── Mundaneum (id: Q451, occurrences: 32)
# │   ├── Wiktionary (id: Q151, occurrences: 32)
# │   ├── tantalum (id: Q1123, occurrences: 32)
# │   ├── Mount Vesuvius (id: Q524, occurrences: 32)
# │   ├── Q1676 (id: Q1676, occurrences: 32)
# │   ├── Lombardy (id: Q1210, occurrences: 32)
# │   ├── Monaco (id: Q235, occurrences: 32)
# │   ├── Bayugan (id: Q1694, occurrences: 32)
# │   ├── Araneae (id: Q1357, occurrences: 32)
# │   ├── New York City (id: Q60, occurrences: 32)
# │   ├── Baghdad (id: Q1530, occurrences: 32)
# │   ├── Athens (id: Q1524, occurrences: 32)
# │   ├── roundabout (id: Q1525, occurrences: 32)
# │   ├── Gare de Lyon-Perrache (id: Q1992, occurrences: 32)
# │   ├── Groß Borstel (id: Q1172, occurrences: 32)
# │   ├── God in Christianity (id: Q825, occurrences: 32)
# │   ├── Graian Alps (id: Q1262, occurrences: 32)
# │   ├── Colorado (id: Q1261, occurrences: 32)
# │   ├── Friuli Venezia Giulia (id: Q1250, occurrences: 32)
# │   ├── Pittsburgh (id: Q1342, occurrences: 32)
# │   ├── Q698 (id: Q698, occurrences: 32)
# │   ├── Prytanée National Militaire (id: Q271, occurrences: 32)
# │   ├── opera (id: Q1344, occurrences: 32)
# │   ├── seaborgium (id: Q1234, occurrences: 32)
# │   ├── tungsten (id: Q743, occurrences: 32)
# │   ├── Turkish (id: Q256, occurrences: 32)
# │   ├── nitrogen (id: Q627, occurrences: 32)
# │   ├── Q378 (id: Q378, occurrences: 32)
# │   ├── Maine (id: Q724, occurrences: 32)
# │   ├── Q251 (id: Q251, occurrences: 32)
# │   ├── Place Bellecour (id: Q614, occurrences: 32)
# │   ├── May (id: Q119, occurrences: 32)
# │   ├── Moscow Oblast (id: Q1697, occurrences: 32)
# │   ├── Tripura (id: Q1363, occurrences: 32)
# │   ├── Saxony (id: Q1202, occurrences: 32)
# │   ├── wireless communication (id: Q249, occurrences: 32)
# │   ├── Dortmund (id: Q1295, occurrences: 32)
# │   ├── science (id: Q336, occurrences: 32)
# │   ├── potassium (id: Q703, occurrences: 32)
# │   ├── Tagbilaran (id: Q1826, occurrences: 32)
# │   ├── Tonga (id: Q678, occurrences: 32)
# │   ├── silicon (id: Q670, occurrences: 32)
# │   ├── La Flèche (id: Q343, occurrences: 32)
# │   ├── hydraulic ram (id: Q661, occurrences: 32)
# │   ├── Stellingen (id: Q1621, occurrences: 32)
# │   ├── corporal punishment (id: Q305, occurrences: 32)
# │   ├── Steinwerder (id: Q1582, occurrences: 32)
# │   ├── Zeeland (id: Q705, occurrences: 32)
# │   ├── calcium (id: Q706, occurrences: 32)
# │   ├── winter (id: Q1311, occurrences: 32)
# │   ├── astronomical unit (id: Q1811, occurrences: 32)
# │   ├── Omsk (id: Q898, occurrences: 32)
# │   ├── space (id: Q107, occurrences: 32)
# │   ├── Concepción (id: Q1880, occurrences: 32)
# │   ├── Sasel (id: Q1821, occurrences: 32)
# │   ├── scientist (id: Q901, occurrences: 32)
# │   ├── Sicily (id: Q1460, occurrences: 32)
# │   ├── Abbekerk (id: Q969, occurrences: 32)
# │   ├── Q102 (id: Q102, occurrences: 32)
# │   ├── Supercalifragilisticexpialidocious (id: Q103, occurrences: 32)
# │   ├── Triglav (id: Q1024, occurrences: 32)
# │   ├── Pacific Ocean (id: Q98, occurrences: 32)
# │   ├── Petrozavodsk (id: Q1895, occurrences: 31)
# │   ├── Universe (id: Q1, occurrences: 31)
# │   ├── Catholicism (id: Q1841, occurrences: 31)
# │   ├── West Flanders (id: Q1113, occurrences: 31)
# │   ├── caesium (id: Q1108, occurrences: 31)
# │   ├── cadmium (id: Q1091, occurrences: 31)
# │   ├── Lemsahl-Mellingstedt (id: Q1815, occurrences: 31)
# │   ├── Marienthal (id: Q1816, occurrences: 31)
# │   ├── Samara Governorate (id: Q1746, occurrences: 31)
# │   ├── Munich (id: Q1726, occurrences: 31)
# │   ├── Oingt (id: Q1983, occurrences: 31)
# │   ├── Q947 (id: Q947, occurrences: 31)
# │   ├── fluorine (id: Q650, occurrences: 31)
# │   ├── checkers (id: Q1293, occurrences: 31)
# │   ├── Antipolo (id: Q1636, occurrences: 31)
# │   ├── Pasig (id: Q1624, occurrences: 31)
# │   ├── Blankenese (id: Q1607, occurrences: 31)
# │   ├── Q1590 (id: Q1590, occurrences: 31)
# │   ├── neon (id: Q654, occurrences: 31)
# │   ├── Moscow (id: Q649, occurrences: 31)
# │   ├── Trentino-South Tyrol (id: Q1237, occurrences: 31)
# │   ├── Indian Ocean (id: Q1239, occurrences: 31)
# │   ├── space race (id: Q1932, occurrences: 31)
# │   ├── Murmansk (id: Q1763, occurrences: 31)
# │   ├── Vidov (id: Q299, occurrences: 31)
# │   ├── scandium (id: Q713, occurrences: 31)
# │   ├── Metallic tower of Fourvière (id: Q625, occurrences: 31)
# │   ├── vodka (id: Q374, occurrences: 31)
# │   ├── Wikiquote (id: Q369, occurrences: 31)
# │   ├── HC Lada Togliatti (id: Q1349, occurrences: 31)
# │   ├── tobacco (id: Q1566, occurrences: 31)
# │   ├── Berlin (id: Q64, occurrences: 31)
# │   ├── Neuwerk (id: Q1622, occurrences: 31)
# │   ├── Lugdunum (id: Q665, occurrences: 31)
# │   ├── !!! (id: Q371, occurrences: 31)
# │   ├── Internet Archive (id: Q461, occurrences: 31)
# │   ├── Europe (id: Q46, occurrences: 31)
# │   ├── Matterhorn (id: Q1374, occurrences: 31)
# │   ├── airplane (id: Q197, occurrences: 31)
# │   ├── Reddit (id: Q1136, occurrences: 31)
# │   ├── Q57 (id: Q57, occurrences: 31)
# │   ├── Vistula (id: Q548, occurrences: 31)
# │   ├── Potsdam (id: Q1711, occurrences: 31)
# │   ├── Q171 (id: Q171, occurrences: 31)
# │   ├── monkey (id: Q1367, occurrences: 31)
# │   ├── animal rights (id: Q426, occurrences: 31)
# │   ├── Haumea (id: Q601, occurrences: 31)
# │   ├── Latin (id: Q397, occurrences: 31)
# │   ├── osmium (id: Q751, occurrences: 31)
# │   ├── Mainz (id: Q1720, occurrences: 31)
# │   ├── Q383 (id: Q383, occurrences: 31)
# │   ├── Virginia (id: Q1370, occurrences: 31)
# │   ├── Lake Michigan (id: Q1169, occurrences: 31)
# │   ├── Randstad (id: Q806, occurrences: 31)
# │   ├── Old Bazaar (id: Q387, occurrences: 31)
# │   ├── Don (id: Q1229, occurrences: 31)
# │   ├── Washington (id: Q1223, occurrences: 31)
# │   ├── England (id: Q21, occurrences: 31)
# │   ├── Volkswagen Golf (id: Q247, occurrences: 31)
# │   ├── Q253 (id: Q253, occurrences: 31)
# │   ├── Utrecht (id: Q776, occurrences: 31)
# │   ├── plant (id: Q756, occurrences: 31)
# │   ├── New Hampshire (id: Q759, occurrences: 31)
# │   ├── Scotland (id: Q22, occurrences: 31)
# │   ├── Poznań (id: Q268, occurrences: 31)
# │   ├── Nova Gorica (id: Q1018, occurrences: 31)
# │   ├── west (id: Q679, occurrences: 31)
# │   ├── Marche (id: Q1279, occurrences: 31)
# │   ├── Umbria (id: Q1280, occurrences: 31)
# │   ├── ruthenium (id: Q1086, occurrences: 31)
# │   ├── history (id: Q309, occurrences: 31)
# │   ├── Père Lachaise Cemetery (id: Q311, occurrences: 31)
# │   ├── Baguio (id: Q1822, occurrences: 31)
# │   ├── Saint-Tropez (id: Q1813, occurrences: 31)
# │   ├── tin (id: Q1096, occurrences: 31)
# │   ├── selenium (id: Q876, occurrences: 31)
# │   ├── gallium (id: Q861, occurrences: 31)
# │   ├── Rajasthan (id: Q1437, occurrences: 31)
# │   ├── Nice model (id: Q1120, occurrences: 31)
# │   ├── sky (id: Q527, occurrences: 31)
# │   ├── Q528 (id: Q528, occurrences: 31)
# │   ├── Olympus Mons (id: Q520, occurrences: 31)
# │   ├── physiology (id: Q521, occurrences: 31)
# │   ├── Q1765 (id: Q1765, occurrences: 31)
# │   ├── village (id: Q532, occurrences: 31)
# │   ├── dysprosium (id: Q1843, occurrences: 31)
# │   ├── FIS Alpine Ski World Cup (id: Q982, occurrences: 31)
# │   ├── Tomsk (id: Q976, occurrences: 31)
# │   ├── Buenos Aires (id: Q1486, occurrences: 31)
# │   ├── meme (id: Q978, occurrences: 30)
# │   ├── Eschwege (id: Q1468, occurrences: 30)
# │   ├── Murmansk Oblast (id: Q1759, occurrences: 30)
# │   ├── Citrus × limon (id: Q500, occurrences: 30)
# │   ├── Prince Eugens Waldemarsudde (id: Q537, occurrences: 30)
# │   ├── Wanfried (id: Q1432, occurrences: 30)
# │   ├── North Carolina (id: Q1454, occurrences: 30)
# │   ├── Calabria (id: Q1458, occurrences: 30)
# │   ├── Wanfried agreement (id: Q1441, occurrences: 30)
# │   ├── Q50 (id: Q50, occurrences: 30)
# │   ├── James Bond (id: Q844, occurrences: 30)
# │   ├── Rhaetian Alps (id: Q1277, occurrences: 30)
# │   ├── darmstadtium (id: Q1266, occurrences: 30)
# │   ├── Pennine Alps (id: Q1270, occurrences: 30)
# │   ├── Volksdorf (id: Q1831, occurrences: 30)
# │   ├── jansenism (id: Q1287, occurrences: 30)
# │   ├── Lepontine Alps (id: Q1274, occurrences: 30)
# │   ├── Perm (id: Q915, occurrences: 30)
# │   ├── Sing for your life (id: Q1080, occurrences: 30)
# │   ├── terbium (id: Q1838, occurrences: 30)
# │   ├── Aachen (id: Q1017, occurrences: 30)
# │   ├── Basilicata (id: Q1452, occurrences: 30)
# │   ├── Forth Bridge (id: Q275, occurrences: 30)
# │   ├── Kilchoman distillery (id: Q277, occurrences: 30)
# │   ├── Rijeka (id: Q1647, occurrences: 30)
# │   ├── square (id: Q164, occurrences: 30)
# │   ├── Saarland (id: Q1201, occurrences: 30)
# │   ├── Thuringia (id: Q1205, occurrences: 30)
# │   ├── Lower Saxony (id: Q1197, occurrences: 30)
# │   ├── fungi (id: Q764, occurrences: 30)
# │   ├── Q12 (id: Q12, occurrences: 30)
# │   ├── June (id: Q120, occurrences: 30)
# │   ├── chromium (id: Q725, occurrences: 30)
# │   ├── manganese (id: Q731, occurrences: 30)
# │   ├── pi (id: Q168, occurrences: 30)
# │   ├── croque-madame (id: Q746, occurrences: 30)
# │   ├── Aosta Valley (id: Q1222, occurrences: 30)
# │   ├── Wyoming (id: Q1214, occurrences: 30)
# │   ├── 2003 (id: Q1986, occurrences: 30)
# │   ├── virus (id: Q808, occurrences: 30)
# │   ├── Valsonne (id: Q1548, occurrences: 30)
# │   ├── Amplepuis (id: Q1549, occurrences: 30)
# │   ├── Saint-Just-d'Avray (id: Q1534, occurrences: 30)
# │   ├── Minnesota (id: Q1527, occurrences: 30)
# │   ├── money (id: Q1368, occurrences: 30)
# │   ├── rook (id: Q137, occurrences: 30)
# │   ├── Chelicerata (id: Q1359, occurrences: 30)
# │   ├── Chennai (id: Q1352, occurrences: 30)
# │   ├── Lisbon (id: Q597, occurrences: 30)
# │   ├── Pcim (id: Q429, occurrences: 30)
# │   ├── cuneiform (id: Q401, occurrences: 30)
# │   ├── Iserlohn (id: Q1130, occurrences: 30)
# │   ├── Borken (id: Q453, occurrences: 30)
# │   ├── Q1495 (id: Q1495, occurrences: 30)
# │   ├── dinosaur (id: Q430, occurrences: 30)
# │   ├── Crohn's disease (id: Q1472, occurrences: 30)
# │   ├── Rhône-Alpes (id: Q463, occurrences: 30)
# │   ├── DBpedia (id: Q465, occurrences: 30)
# │   ├── Lake Huron (id: Q1383, occurrences: 30)
# │   ├── São Paulo (id: Q175, occurrences: 30)
# │   ├── Alfa Romeo 159 (id: Q1610, occurrences: 30)
# │   ├── Neuwerk (id: Q1577, occurrences: 30)
# │   ├── Kleiner Grasbrook (id: Q1573, occurrences: 30)
# │   ├── Lyon Metro (id: Q1552, occurrences: 30)
# │   ├── Simeon (id: Q1557, occurrences: 30)
# │   ├── Wales (id: Q25, occurrences: 30)
# │   ├── oxygen (id: Q629, occurrences: 30)
# │   ├── Q259 (id: Q259, occurrences: 30)
# │   ├── pawn (id: Q135, occurrences: 30)
# │   ├── optical aberration (id: Q639, occurrences: 30)
# │   ├── Swedish Chef (id: Q700, occurrences: 30)
# │   ├── Ardbeg (id: Q274, occurrences: 30)
# │   ├── ciao (id: Q831, occurrences: 30)
# │   ├── Riga (id: Q1773, occurrences: 30)
# │   ├── December (id: Q126, occurrences: 30)
# │   ├── The Beatles (id: Q1299, occurrences: 30)
# │   ├── Uranus (id: Q324, occurrences: 30)
# │   ├── south (id: Q667, occurrences: 30)
# │   ├── Ghent (id: Q1296, occurrences: 30)
# │   ├── quantum mechanics (id: Q944, occurrences: 30)
# │   ├── Reggiolo (id: Q952, occurrences: 30)
# │   ├── Stuttgart (id: Q1022, occurrences: 30)
# │   ├── Poppenbüttel (id: Q1818, occurrences: 30)
# │   ├── Hamburg (id: Q1055, occurrences: 30)
# │   ├── Q1869 (id: Q1869, occurrences: 30)
# │   ├── OpenStreetMap (id: Q936, occurrences: 30)
# │   ├── nobelium (id: Q1901, occurrences: 30)
# │   ├── californium (id: Q1888, occurrences: 30)
# │   ├── mercury (id: Q925, occurrences: 30)
# │   ├── Madagascar (id: Q1019, occurrences: 29)
# │   ├── Q104 (id: Q104, occurrences: 29)
# │   ├── Makati (id: Q1508, occurrences: 29)
# │   ├── AC Milan (id: Q1543, occurrences: 29)
# │   ├── astrobiology (id: Q411, occurrences: 29)
# │   ├── Higgs boson (id: Q402, occurrences: 29)
# │   ├── Bibliotheca universalis (id: Q445, occurrences: 29)
# │   ├── mind (id: Q450, occurrences: 29)
# │   ├── Limburg (id: Q1095, occurrences: 29)
# │   ├── Berlin Central Station (id: Q1097, occurrences: 29)
# │   ├── diplomacy (id: Q1889, occurrences: 29)
# │   ├── Asia (id: Q48, occurrences: 29)
# │   ├── Don Quixote (id: Q480, occurrences: 29)
# │   ├── friendship (id: Q491, occurrences: 29)
# │   ├── cigarette (id: Q1578, occurrences: 29)
# │   ├── armpit (id: Q499, occurrences: 29)
# │   ├── laziness (id: Q484, occurrences: 29)
# │   ├── Ronno (id: Q1539, occurrences: 29)
# │   ├── googolplex (id: Q508, occurrences: 29)
# │   ├── HafenCity (id: Q1561, occurrences: 29)
# │   ├── Neustadt (id: Q1554, occurrences: 29)
# │   ├── Pluto (id: Q339, occurrences: 29)
# │   ├── time capsule (id: Q348, occurrences: 29)
# │   ├── Goa (id: Q1171, occurrences: 29)
# │   ├── José Ballivián Province (id: Q827, occurrences: 29)
# │   ├── Andhra Pradesh (id: Q1159, occurrences: 29)
# │   ├── Bihar (id: Q1165, occurrences: 29)
# │   ├── Hainaut (id: Q1129, occurrences: 29)
# │   ├── Q1134 (id: Q1134, occurrences: 29)
# │   ├── Capsicum annuum (id: Q1380, occurrences: 29)
# │   ├── New York (id: Q1384, occurrences: 29)
# │   ├── Battle of Nieuwpoort (id: Q1392, occurrences: 29)
# │   ├── Villeurbanne (id: Q582, occurrences: 29)
# │   ├── Microsoft Windows (id: Q1406, occurrences: 29)
# │   ├── Ohio (id: Q1397, occurrences: 29)
# │   ├── Veddel (id: Q1583, occurrences: 29)
# │   ├── Venus (id: Q313, occurrences: 29)
# │   ├── love (id: Q316, occurrences: 29)
# │   ├── Eris (id: Q611, occurrences: 29)
# │   ├── Delhi (id: Q1353, occurrences: 29)
# │   ├── human sexual behavior (id: Q608, occurrences: 29)
# │   ├── Altona-Altstadt (id: Q1591, occurrences: 29)
# │   ├── University of Maribor (id: Q1378, occurrences: 29)
# │   ├── Gran Paradiso (id: Q1372, occurrences: 29)
# │   ├── Iona (id: Q610, occurrences: 29)
# │   ├── television (id: Q289, occurrences: 29)
# │   ├── Po (id: Q643, occurrences: 29)
# │   ├── Neva (id: Q645, occurrences: 29)
# │   ├── Zwolle (id: Q793, occurrences: 29)
# │   ├── stupidity (id: Q795, occurrences: 29)
# │   ├── epitaph (id: Q1772, occurrences: 29)
# │   ├── Zanzibar Islands (id: Q1774, occurrences: 29)
# │   ├── Vologda (id: Q1957, occurrences: 29)
# │   ├── Dième (id: Q1966, occurrences: 29)
# │   ├── Auvergne (id: Q1152, occurrences: 29)
# │   ├── Philadelphia (id: Q1345, occurrences: 29)
# │   ├── mixed-member proportional representation (id: Q133, occurrences: 29)
# │   ├── planet (id: Q634, occurrences: 29)
# │   ├── Maastricht (id: Q1309, occurrences: 29)
# │   ├── Kolkata (id: Q1348, occurrences: 29)
# │   ├── Chicago (id: Q1297, occurrences: 29)
# │   ├── leet (id: Q1337, occurrences: 29)
# │   ├── Ems (id: Q1648, occurrences: 29)
# │   ├── Dolomites (id: Q1283, occurrences: 29)
# │   ├── Grenoble (id: Q1289, occurrences: 29)
# │   ├── phosphorus (id: Q674, occurrences: 29)
# │   ├── Danube (id: Q1653, occurrences: 29)
# │   ├── computer (id: Q68, occurrences: 29)
# │   ├── Courrendlin (id: Q69, occurrences: 29)
# │   ├── Barbados (id: Q244, occurrences: 29)
# │   ├── Main (id: Q1670, occurrences: 29)
# │   ├── Limousin (id: Q1190, occurrences: 29)
# │   ├── war (id: Q198, occurrences: 29)
# │   ├── Formula One (id: Q1968, occurrences: 29)
# │   ├── 2000 (id: Q1985, occurrences: 29)
# │   ├── volleyball (id: Q1734, occurrences: 29)
# │   ├── Emilia-Romagna (id: Q1263, occurrences: 29)
# │   ├── Olympique Lyonnais (id: Q704, occurrences: 29)
# │   ├── Q200 (id: Q200, occurrences: 29)
# │   ├── Alster (id: Q1219, occurrences: 29)
# │   ├── rakfisk (id: Q208, occurrences: 29)
# │   ├── right angle (id: Q210, occurrences: 29)
# │   ├── Ukraine (id: Q212, occurrences: 29)
# │   ├── Tabaco (id: Q1706, occurrences: 29)
# │   ├── Monday (id: Q105, occurrences: 29)
# │   ├── technetium (id: Q1054, occurrences: 29)
# │   ├── metabolism (id: Q1057, occurrences: 29)
# │   ├── Equatorial Guinea (id: Q983, occurrences: 29)
# │   ├── Gujarat (id: Q1061, occurrences: 29)
# │   ├── strontium (id: Q938, occurrences: 29)
# │   ├── Chukchi Peninsula (id: Q1002, occurrences: 29)
# │   ├── Miles Franklin Literary Award (id: Q996, occurrences: 29)
# │   ├── color (id: Q1075, occurrences: 29)
# │   ├── Gangnam Style (id: Q890, occurrences: 29)
# │   ├── Wellingsbüttel (id: Q1836, occurrences: 29)
# │   ├── Aceh (id: Q1823, occurrences: 29)
# │   ├── South Pole (id: Q933, occurrences: 29)
# │   ├── rhodium (id: Q1087, occurrences: 29)
# │   ├── Mississippi River (id: Q1497, occurrences: 28)
# │   ├── thallium (id: Q932, occurrences: 28)
# │   ├── place des Terreaux (id: Q1506, occurrences: 28)
# │   ├── Q462 (id: Q462, occurrences: 28)
# │   ├── Asahan (id: Q1795, occurrences: 28)
# │   ├── Wikimedia Foundation (id: Q180, occurrences: 28)
# │   ├── Q1887 (id: Q1887, occurrences: 28)
# │   ├── North America (id: Q49, occurrences: 28)
# │   ├── memory (id: Q492, occurrences: 28)
# │   ├── The Library of Babel (id: Q473, occurrences: 28)
# │   ├── Craniopagus parasiticus (id: Q1483, occurrences: 28)
# │   ├── Sofia (id: Q472, occurrences: 28)
# │   ├── European Union (id: Q458, occurrences: 28)
# │   ├── field hockey (id: Q1455, occurrences: 28)
# │   ├── Chernobyl disaster (id: Q486, occurrences: 28)
# │   ├── atomic bombings of Hiroshima and Nagasaki (id: Q488, occurrences: 28)
# │   ├── Antarctica (id: Q51, occurrences: 28)
# │   ├── chess (id: Q718, occurrences: 28)
# ...
# │   ├── Aníbal Zañartu (id: Q1318, occurrences: 34)
# │   ├── Germán Riesco (id: Q1300, occurrences: 34)
# │   ├── André-Marie Ampère (id: Q675, occurrences: 34)
# │   ├── Neil Armstrong (id: Q1615, occurrences: 34)
# │   ├── Elvis Presley (id: Q303, occurrences: 34)
# │   ├── Dejen Gebremeskel (id: Q1672, occurrences: 34)
# │   ├── Pertinax (id: Q1436, occurrences: 34)
# │   ├── Fyodor Dostoyevsky (id: Q991, occurrences: 33)
# │   ├── Kim Wilde (id: Q1790, occurrences: 33)
# │   ├── Leonel Suárez (id: Q1796, occurrences: 33)
# │   ├── Eric Abidal (id: Q1935, occurrences: 33)
# │   ├── Robert Harting (id: Q1766, occurrences: 33)
# │   ├── Mitchell Watt (id: Q1747, occurrences: 33)
# │   ├── Abou Diaby (id: Q1943, occurrences: 33)
# │   ├── Anja Pärson (id: Q1933, occurrences: 33)
# │   ├── Hatem Ben Arfa (id: Q1928, occurrences: 33)
# │   ├── Sidney Govou (id: Q1934, occurrences: 33)
# │   ├── Gustav Thöni (id: Q1955, occurrences: 33)
# │   ├── Jorge Luis Borges (id: Q909, occurrences: 33)
# │   ├── Édith Piaf (id: Q1631, occurrences: 33)
# │   ├── Eduardo Frei Ruiz-Tagle (id: Q326, occurrences: 33)
# │   ├── Ricardo Lagos (id: Q331, occurrences: 33)
# │   ├── Dag Hammarskjöld (id: Q1267, occurrences: 33)
# │   ├── Ban Ki-moon (id: Q1253, occurrences: 33)
# │   ├── Paul Morand (id: Q272, occurrences: 33)
# │   ├── Friedrich Hayek (id: Q1325, occurrences: 33)
# │   ├── Wolfgang Amadeus Mozart (id: Q254, occurrences: 33)
# │   ├── François Hollande (id: Q157, occurrences: 33)
# │   ├── Ezekiel Kemboi (id: Q1677, occurrences: 33)
# │   ├── Konstantin Melnikov (id: Q930, occurrences: 33)
# │   ├── Charles Baudelaire (id: Q501, occurrences: 33)
# │   ├── Miles Franklin (id: Q984, occurrences: 33)
# │   ├── Émile Zola (id: Q504, occurrences: 33)
# │   ├── Greg Rutherford (id: Q1745, occurrences: 32)
# │   ├── Madonna (id: Q1744, occurrences: 32)
# │   ├── Indira Gandhi (id: Q1149, occurrences: 32)
# │   ├── Djibril Cissé (id: Q1936, occurrences: 32)
# │   ├── Commodus (id: Q1434, occurrences: 32)
# │   ├── Paul Otlet (id: Q1868, occurrences: 32)
# │   ├── Ken Jennings (id: Q186, occurrences: 32)
# │   ├── Maximinus Thrax (id: Q1777, occurrences: 32)
# │   ├── Linda Lovelace (id: Q407, occurrences: 32)
# │   ├── Justin Gatlin (id: Q1652, occurrences: 32)
# │   ├── Francesco Cossiga (id: Q1230, occurrences: 32)
# │   ├── Tony Garnier (id: Q1544, occurrences: 32)
# │   ├── John Lennon (id: Q1203, occurrences: 32)
# │   ├── Roman Camenzind (id: Q1023, occurrences: 32)
# │   ├── Jawaharlal Nehru (id: Q1047, occurrences: 32)
# │   ├── Julius Caesar (id: Q1048, occurrences: 31)
# │   ├── Carl Linnaeus (id: Q1043, occurrences: 31)
# │   ├── Harry Mulisch (id: Q927, occurrences: 31)
# │   ├── Gordian II (id: Q1803, occurrences: 31)
# │   ├── Pedro I of Brazil (id: Q939, occurrences: 31)
# │   ├── Andrei Tarkovsky (id: Q853, occurrences: 31)
# │   ├── Florent Malouda (id: Q1913, occurrences: 31)
# │   ├── Mahatma Gandhi (id: Q1001, occurrences: 31)
# │   ├── Robert Grabarz (id: Q1738, occurrences: 31)
# │   ├── Osama bin Laden (id: Q1317, occurrences: 31)
# │   ├── Primo Nebiolo (id: Q1638, occurrences: 31)
# │   ├── Luigi Galvani (id: Q1589, occurrences: 31)
# │   ├── Javier Pérez de Cuéllar (id: Q1259, occurrences: 31)
# │   ├── Brownie Mary (id: Q1775, occurrences: 31)
# │   ├── Manuel Bulnes (id: Q1329, occurrences: 31)
# │   ├── José Joaquín Prieto (id: Q1330, occurrences: 31)
# │   ├── Nicolaus Copernicus (id: Q619, occurrences: 31)
# │   ├── Julian Assange (id: Q360, occurrences: 31)
# │   ├── Giovanni Boccaccio (id: Q1402, occurrences: 31)
# │   ├── Renaud Lavillenie (id: Q1742, occurrences: 31)
# │   ├── Maria Walliser (id: Q1984, occurrences: 31)
# │   ├── Carlos Ibáñez del Campo (id: Q579, occurrences: 31)
# │   ├── Stephen Kiprotich (id: Q1702, occurrences: 31)
# │   ├── Paul Verlaine (id: Q755, occurrences: 31)
# │   ├── Jean-Baptiste Lully (id: Q1192, occurrences: 31)
# │   ├── Józef Piłsudski (id: Q885, occurrences: 31)
# │   ├── Laurent Blanc (id: Q1839, occurrences: 31)
# │   ├── Adriaan Paulen (id: Q1634, occurrences: 31)
# │   ├── Ella Fitzgerald (id: Q1768, occurrences: 31)
# │   ├── David Storl (id: Q1758, occurrences: 30)
# │   ├── Blaise Matuidi (id: Q1921, occurrences: 30)
# │   ├── Jérémy Ménez (id: Q1923, occurrences: 30)
# │   ├── Alexandra Stan (id: Q1453, occurrences: 30)
# │   ├── Jesus Christ (id: Q302, occurrences: 30)
# │   ├── Hubert Salentin (id: Q1217, occurrences: 30)
# │   ├── Q392 (id: Q392, occurrences: 30)
# │   ├── Pierre Corneille (id: Q747, occurrences: 30)
# │   ├── Wilson Kipsang Kiprotich (id: Q1705, occurrences: 30)
# │   ├── Jenna Jameson (id: Q400, occurrences: 30)
# │   ├── David Cecil, 6th Marquess of Exeter (id: Q1628, occurrences: 30)
# │   ├── Piet Kraak (id: Q354, occurrences: 30)
# │   ├── Alessandro Del Piero (id: Q624, occurrences: 30)
# │   ├── Manuel Montt (id: Q1328, occurrences: 30)
# │   ├── Giovanni Gronchi (id: Q1241, occurrences: 30)
# │   ├── Louis IX of France (id: Q346, occurrences: 30)
# │   ├── Patricio Aylwin (id: Q335, occurrences: 30)
# │   ├── Charles Aznavour (id: Q1785, occurrences: 30)
# │   ├── Hugo Lloris (id: Q1907, occurrences: 30)
# │   ├── Yohan Cabaye (id: Q1910, occurrences: 30)
# │   ├── Trey Hardee (id: Q1793, occurrences: 30)
# │   ├── Pupienus (id: Q1797, occurrences: 30)
# │   ├── Keshorn Walcott (id: Q1787, occurrences: 30)
# │   ├── Memphis Depay (id: Q1894, occurrences: 30)
# │   ├── Lech Wałęsa (id: Q444, occurrences: 29)
# │   ├── Cicero (id: Q1541, occurrences: 29)
# │   ├── Douglas Adams (id: Q42, occurrences: 29)
# │   ├── Primož Kozmus (id: Q1783, occurrences: 29)
# │   ├── Q493 (id: Q493, occurrences: 29)
# │   ├── Augusto Pinochet (id: Q368, occurrences: 29)
# │   ├── Caligula (id: Q1409, occurrences: 29)
# │   ├── Stendhal (id: Q502, occurrences: 29)
# │   ├── Antoninus Pius (id: Q1429, occurrences: 29)
# │   ├── Nicolas Sarkozy (id: Q329, occurrences: 29)
# │   ├── Tomasz Majewski (id: Q1755, occurrences: 29)
# │   ├── Franck Ribéry (id: Q1918, occurrences: 29)
# │   ├── Galileo Galilei (id: Q307, occurrences: 29)
# │   ├── Michael Bloomberg (id: Q607, occurrences: 29)
# │   ├── Diego Velázquez (id: Q297, occurrences: 29)
# │   ├── Vreni Schneider (id: Q1958, occurrences: 29)
# │   ├── Domingo Santa María (id: Q1323, occurrences: 29)
# │   ├── Nijel Amos (id: Q1660, occurrences: 29)
# │   ├── Alessandro Volta (id: Q680, occurrences: 29)
# │   ├── Antonio Segni (id: Q1240, occurrences: 29)
# │   ├── Luigi Einaudi (id: Q1242, occurrences: 29)
# │   ├── Tariku Bekele (id: Q1674, occurrences: 29)
# │   ├── Björn Otto (id: Q1743, occurrences: 29)
# │   ├── Will Claye (id: Q1750, occurrences: 29)
# │   ├── George W. Bush (id: Q207, occurrences: 29)
# │   ├── Serge Gainsbourg (id: Q1698, occurrences: 29)
# │   ├── Julio Bashmore (id: Q1081, occurrences: 29)
# │   ├── Alessandro Manzoni (id: Q1064, occurrences: 29)
# │   ├── Robert Louis Stevenson (id: Q1512, occurrences: 28)
# │   ├── Ashton Eaton (id: Q1789, occurrences: 28)
# │   ├── Jan II Carondelet (id: Q1791, occurrences: 28)
# │   ├── Eduardo Frei Montalva (id: Q475, occurrences: 28)
# │   ├── Bill Maher (id: Q489, occurrences: 28)
# │   ├── Stephen Harper (id: Q206, occurrences: 28)
# │   ├── Carlo Azeglio Ciampi (id: Q1224, occurrences: 28)
# │   ├── Oscar Luigi Scalfaro (id: Q1228, occurrences: 28)
# │   ├── Nesta Carter (id: Q1699, occurrences: 28)
# │   ├── William Shakespeare (id: Q692, occurrences: 28)
# │   ├── Abdalaati Iguider (id: Q1669, occurrences: 28)
# │   ├── Maurice Ravel (id: Q1178, occurrences: 28)
# │   ├── Jean Racine (id: Q742, occurrences: 28)
# │   ├── Marcus Aurelius (id: Q1430, occurrences: 28)
# │   ├── Nerva (id: Q1424, occurrences: 28)
# │   ├── Vespasian (id: Q1419, occurrences: 28)
# │   ├── Q557 (id: Q557, occurrences: 28)
# │   ├── Andrei Rublev (id: Q838, occurrences: 28)
# │   ├── Niccolò Machiavelli (id: Q1399, occurrences: 28)
# │   ├── El Greco (id: Q301, occurrences: 28)
# │   ├── Q590 (id: Q590, occurrences: 28)
# │   ├── Hector Berlioz (id: Q1151, occurrences: 28)
# │   ├── Aníbal Pinto (id: Q1324, occurrences: 28)
# │   ├── Federico Errázuriz Zañartu (id: Q1326, occurrences: 28)
# │   ├── Manuel Blanco Encalada (id: Q1331, occurrences: 28)
# │   ├── Yohan Blake (id: Q1651, occurrences: 28)
# │   ├── Neil Young (id: Q633, occurrences: 28)
# │   ├── Ehsan Hadadi (id: Q1771, occurrences: 28)
# │   ├── Gerd Kanter (id: Q1776, occurrences: 28)
# │   ├── Harald Krichel (id: Q640, occurrences: 28)
# │   ├── Erika Hess (id: Q1962, occurrences: 28)
# │   ├── Alberto Tomba (id: Q1950, occurrences: 28)
# │   ├── Jérémy Toulalan (id: Q1944, occurrences: 28)
# │   ├── Juan Luis Sanfuentes (id: Q857, occurrences: 28)
# │   ├── Manuel L. Quezon (id: Q1503, occurrences: 28)
# │   ├── Socrates (id: Q913, occurrences: 27)
# │   ├── Gordian III (id: Q1812, occurrences: 27)
# │   ├── Dante Alighieri (id: Q1067, occurrences: 27)
# │   ├── J. R. R. Tolkien (id: Q892, occurrences: 27)
# │   ├── Andrei Sakharov (id: Q997, occurrences: 27)
# │   ├── Albert Einstein (id: Q937, occurrences: 27)
# │   ├── Aristotle (id: Q868, occurrences: 27)
# │   ├── Marvin Martin (id: Q1927, occurrences: 27)
# │   ├── William Gallas (id: Q1937, occurrences: 27)
# │   ├── Taoufik Makhloufi (id: Q1665, occurrences: 27)
# │   ├── Kirani James (id: Q1655, occurrences: 27)
# │   ├── Ramón Barros Luco (id: Q1294, occurrences: 27)
# │   ├── Gabriel Gonzáles Videla (id: Q815, occurrences: 27)
# │   ├── Michelle Bachelet (id: Q320, occurrences: 27)
# │   ├── Sebastián Piñera (id: Q306, occurrences: 27)
# │   ├── Bill Clinton (id: Q1124, occurrences: 27)
# │   ├── Mathieu Debuchy (id: Q1908, occurrences: 27)
# │   ├── Adil Rami (id: Q1909, occurrences: 27)
# │   ├── Hadrian (id: Q1427, occurrences: 27)
# │   ├── Claudius (id: Q1411, occurrences: 27)
# │   ├── Otho (id: Q1416, occurrences: 27)
# │   ├── Q762 (id: Q762, occurrences: 27)
# │   ├── Christian Taylor (id: Q1751, occurrences: 27)
# │   ├── Ivan Ukhov (id: Q1732, occurrences: 27)
# │   ├── Usain Bolt (id: Q1189, occurrences: 27)
# │   ├── George Washington (id: Q23, occurrences: 27)
# │   ├── Michela Figini (id: Q1991, occurrences: 27)
# │   ├── Genghis Khan (id: Q720, occurrences: 27)
# │   ├── Ramesses IV (id: Q1532, occurrences: 27)
# │   ├── Yanka Kupala (id: Q377, occurrences: 27)
# │   ├── Claude I Carondelet (id: Q1788, occurrences: 27)
# │   ├── François Villon (id: Q849, occurrences: 26)
# │   ├── Ramesses II (id: Q1523, occurrences: 26)
# │   ├── Ramesses III (id: Q1528, occurrences: 26)
# │   ├── Galba (id: Q1414, occurrences: 26)
# │   ├── Dario Fo (id: Q765, occurrences: 26)
# │   ├── Mutaz Essa Barshim (id: Q1739, occurrences: 26)
# │   ├── Robert Brasillach (id: Q1488, occurrences: 26)
# │   ├── Napoleon (id: Q517, occurrences: 26)
# │   ├── Sigfrid Edström (id: Q1625, occurrences: 26)
# │   ├── Antonio Vivaldi (id: Q1340, occurrences: 26)
# │   ├── Tim Lincecum (id: Q1604, occurrences: 26)
# │   ├── Ramón Freire (id: Q1332, occurrences: 26)
# │   ├── José Joaquín Pérez (id: Q1327, occurrences: 26)
# │   ├── Richard Wagner (id: Q1511, occurrences: 26)
# │   ├── Luguelín Santos (id: Q1656, occurrences: 26)
# │   ├── Lamine Diack (id: Q1639, occurrences: 26)
# │   ├── Stevie Wonder (id: Q714, occurrences: 26)
# │   ├── Hansle Parchment (id: Q1687, occurrences: 26)
# │   ├── Petrarch (id: Q1401, occurrences: 26)
# │   ├── Abel Mutai (id: Q1681, occurrences: 26)
# │   ├── Jean-François Champollion (id: Q260, occurrences: 26)
# │   ├── Kurt Waldheim (id: Q1260, occurrences: 26)
# │   ├── Leonard Cohen (id: Q1276, occurrences: 26)
# │   ├── Jorge Montt (id: Q1320, occurrences: 26)
# │   ├── Vitellius (id: Q1417, occurrences: 25)
# │   ├── Olivier Giroud (id: Q1911, occurrences: 25)
# │   ├── Yann M'Vila (id: Q1925, occurrences: 25)
# │   ├── Reese Hoffa (id: Q1760, occurrences: 25)
# │   ├── Warren Weir (id: Q1654, occurrences: 25)
# │   ├── Vladimir Lenin (id: Q1394, occurrences: 25)
# │   ├── Aries Merritt (id: Q1683, occurrences: 25)
# │   ├── Luigi Pirandello (id: Q1403, occurrences: 25)
# │   ├── Q76 (id: Q76, occurrences: 25)
# │   ├── Victor Hugo (id: Q535, occurrences: 25)
# │   ├── Ingemar Stenmark (id: Q530, occurrences: 25)
# │   ├── Cleopatra (id: Q635, occurrences: 25)
# │   ├── Decius (id: Q1830, occurrences: 25)
# │   ├── Isaac Newton (id: Q935, occurrences: 25)
# │   ├── Ivan Regen (id: Q1051, occurrences: 25)
# │   ├── Italo Balbo (id: Q1056, occurrences: 25)
# │   ├── Charles Darwin (id: Q1035, occurrences: 24)
# │   ├── Georges Brassens (id: Q449, occurrences: 24)
# │   ├── José Manuel Balmaceda (id: Q1322, occurrences: 24)
# │   ├── Johann Sebastian Bach (id: Q1339, occurrences: 24)
# │   ├── Bruno Mars (id: Q1450, occurrences: 24)
# │   ├── Mikhail Bulgakov (id: Q835, occurrences: 24)
# │   ├── Giorgio Napolitano (id: Q1220, occurrences: 24)
# │   ├── Sergey Kirdyapkin (id: Q1717, occurrences: 24)
# │   ├── Jason Richardson (id: Q1685, occurrences: 24)
# │   ├── Augustus (id: Q1405, occurrences: 24)
# │   ├── Leo Ortolani (id: Q1395, occurrences: 24)
# │   ├── Gordian I (id: Q1782, occurrences: 24)
# │   ├── Nicolas Anelka (id: Q1939, occurrences: 24)
# │   ├── Stéphane Mallarmé (id: Q767, occurrences: 24)
# │   ├── Roald Amundsen (id: Q926, occurrences: 24)
# │   ├── Charlie Chaplin (id: Q882, occurrences: 24)
# │   ├── Balbinus (id: Q1805, occurrences: 24)
# │   ├── Tiberius (id: Q1407, occurrences: 24)
# │   ├── Hedi Slimane (id: Q558, occurrences: 24)
# │   ├── Kate Bush (id: Q636, occurrences: 23)
# │   ├── Charles Lindbergh (id: Q1618, occurrences: 23)
# │   ├── Jacques Brel (id: Q1666, occurrences: 23)
# │   ├── David Rudisha (id: Q1659, occurrences: 23)
# │   ├── Erik Kynard (id: Q1736, occurrences: 23)
# │   ├── Jared Tallent (id: Q1728, occurrences: 23)
# │   ├── Tim Berners-Lee (id: Q80, occurrences: 23)
# │   ├── Blanche of Castile (id: Q353, occurrences: 23)
# │   ├── Nero (id: Q1413, occurrences: 23)
# │   ├── Domitian (id: Q1423, occurrences: 23)
# │   ├── Renaud (id: Q1716, occurrences: 23)
# │   ├── Mahiedine Mekhissi-Benabbad (id: Q1679, occurrences: 23)
# │   ├── Zinédine Zidane (id: Q1835, occurrences: 22)
# │   ├── Giuseppe Garibaldi (id: Q539, occurrences: 22)
# │   ├── Erick Barrondo (id: Q1712, occurrences: 22)
# │   ├── Bruce Springsteen (id: Q1225, occurrences: 22)
# │   ├── Denis Diderot (id: Q448, occurrences: 22)
# │   ├── Q1514 (id: Q1514, occurrences: 22)
# │   ├── Samir Nasri (id: Q1920, occurrences: 22)
# │   ├── David Cameron (id: Q192, occurrences: 22)
# │   ├── Michael Schmidt-Salomon (id: Q1878, occurrences: 22)
# │   ├── Pedro Montt (id: Q1298, occurrences: 22)
# │   ├── Timothy Kitum (id: Q1662, occurrences: 22)
# │   ├── Angela Merkel (id: Q567, occurrences: 21)
# │   ├── Trajan (id: Q1425, occurrences: 21)
# │   ├── Félix Sánchez (id: Q1689, occurrences: 21)
# │   ├── Jürgen Locadia (id: Q1885, occurrences: 21)
# │   ├── Daniel Balavoine (id: Q1802, occurrences: 21)
# │   ├── Gary Gygax (id: Q1379, occurrences: 21)
# │   ├── Saddam Hussein (id: Q1316, occurrences: 21)
# │   ├── Ludwig van Beethoven (id: Q255, occurrences: 21)
# │   ├── Friedrich Theodor Vischer (id: Q651, occurrences: 21)
# │   ├── Patrice Evra (id: Q1916, occurrences: 21)
# │   ├── Karim Benzema (id: Q1912, occurrences: 21)
# │   ├── Jorge Alessandri (id: Q576, occurrences: 21)
# │   ├── Plato (id: Q859, occurrences: 20)
# │   ├── Arturo Alessandri (id: Q848, occurrences: 20)
# │   ├── U Thant (id: Q1264, occurrences: 19)
# │   ├── Bacary Sagna (id: Q1938, occurrences: 19)
# │   ├── Claude Bourgelat (id: Q559, occurrences: 19)
# │   ├── Salvador Allende (id: Q440, occurrences: 19)
# │   ├── Sabri Lamouchi (id: Q1883, occurrences: 19)
# │   ├── Gladwyn Jebb (id: Q1275, occurrences: 19)
# │   ├── Corentin Martins (id: Q1879, occurrences: 19)
# │   ├── Blaise Pascal (id: Q1290, occurrences: 19)
# │   ├── Benjamin Raich (id: Q1945, occurrences: 19)
# │   ├── Donald Tusk (id: Q946, occurrences: 18)
# │   ├── John Bardeen (id: Q949, occurrences: 18)
# │   ├── Roger Federer (id: Q1426, occurrences: 18)
# │   ├── John Paul II (id: Q989, occurrences: 18)
# │   ├── Ferry Carondelet (id: Q1798, occurrences: 17)
# │   ├── Ulrich Frédéric Woldemar, Comte de Lowendal (id: Q498, occurrences: 14)
# │   └── Giovanni Leone (id: Q1235, occurrences: 14)
# └── Written Work (id: concept_written work)
#     ├── Encyclopédie (id: Q447, occurrences: 28)
#     ├── Natural History (id: Q442, occurrences: 27)
#     └── Encyclopædia Britannica (id: Q455, occurrences: 23)

# %%
# @title Visualize a Pruned (Top 5 per Category) Ontology Tree
import json
from anytree import Node, RenderTree
import os

# --- This cell also assumes Phase 4 has been run ---

PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
ONTOLOGY_PATH = os.path.join(PROJECT_ROOT, "output/final_ontology.json")
MAX_LEAVES_PER_BRANCH = 5 # <--- You can change this number

# 1. Load the ontology from the JSON file
try:
    with open(ONTOLOGY_PATH, 'r') as f:
        data = json.load(f)
except FileNotFoundError:
    print(f"ERROR: The ontology file was not found at {ONTOLOGY_PATH}")
    raise

# 2. Build the pruned tree
root_data = data.get('ontology', {})
root_node_pruned = Node(f"{root_data.get('name', 'Root')} (id: {root_data.get('id')})")

type_nodes_data = root_data.get('children', [])

for type_data in type_nodes_data:
    type_name = type_data.get('name', 'N/A')
    total_entities_in_type = len(type_data.get('children', []))

    # Add the total count to the type node's name for context
    type_node = Node(
        f"{type_name} (Showing top {MAX_LEAVES_PER_BRANCH} of {total_entities_in_type})",
        parent=root_node_pruned
    )

    # Get all entities but only loop through the first few
    entity_nodes_data = type_data.get('children', [])
    for entity_data in entity_nodes_data[:MAX_LEAVES_PER_BRANCH]:
        entity_name = entity_data.get('name', 'N/A')
        entity_id = entity_data.get('id', 'N/A')
        occurrences = entity_data.get('metadata', {}).get('occurrences', 0)

        Node(f"{entity_name} (id: {entity_id}, occurrences: {occurrences})", parent=type_node)

    # If there are more entities than we showed, add an ellipsis node
    if total_entities_in_type > MAX_LEAVES_PER_BRANCH:
        Node("...", parent=type_node)

# 3. Render and print the pruned tree
print(f"--- Pruned Ontology Tree (Top {MAX_LEAVES_PER_BRANCH} Entities per Category) ---")
for pre, _, node in RenderTree(root_node_pruned):
    print(f"{pre}{node.name}")

'''**Explanation of Changes:**
*   **`MAX_LEAVES_PER_BRANCH`**: A variable is introduced to easily control how many entities you want to see per category.
*   **Slicing**: The loop `for entity_data in entity_nodes_data[:MAX_LEAVES_PER_BRANCH]:` now uses list slicing to only iterate over the first 5 items.
*   **Context in Node Name**: The category node now tells you how many total entities it contains (e.g., "Person (Showing top 5 of 127)").
*   **Ellipsis Node**: An "..." node is added at the end of each branch if there were more entities than were displayed, clearly indicating that the view is truncated.'''
# Out:
# --- Pruned Ontology Tree (Top 5 Entities per Category) ---
# Domain (id: root)
# ├── Business (Showing top 5 of 7)
# │   ├── Mercedes-Benz Mobility Services (id: Q1902, occurrences: 40)
# │   ├── Q1418 (id: Q1418, occurrences: 35)
# │   ├── Google (id: Q95, occurrences: 33)
# │   ├── TogliattiAzot (id: Q1343, occurrences: 32)
# │   ├── Juventus FC (id: Q1422, occurrences: 29)
# │   └── ...
# ├── City (Showing top 5 of 88)
# │   ├── Bonn (id: Q586, occurrences: 49)
# │   ├── Jerusalem (id: Q1218, occurrences: 41)
# │   ├── Celje (id: Q1012, occurrences: 41)
# │   ├── Havana (id: Q1563, occurrences: 39)
# │   ├── Caracas (id: Q1533, occurrences: 39)
# │   └── ...
# ├── Country (Showing top 5 of 174)
# │   ├── Sri Lanka (id: Q854, occurrences: 43)
# │   ├── Belarus (id: Q184, occurrences: 42)
# │   ├── Turkmenistan (id: Q874, occurrences: 42)
# │   ├── The Bahamas (id: Q778, occurrences: 41)
# │   ├── Antigua and Barbuda (id: Q781, occurrences: 41)
# │   └── ...
# ├── Film (Showing top 5 of 4)
# │   ├── Swept Away (id: Q1365, occurrences: 35)
# │   ├── A Gang Story (id: Q593, occurrences: 34)
# │   ├── The Intouchables (id: Q595, occurrences: 26)
# │   └── We Live in Public (id: Q372, occurrences: 26)
# ├── Organization (Showing top 5 of 5)
# │   ├── Boeing (id: Q66, occurrences: 38)
# │   ├── Solidarity (id: Q1003, occurrences: 34)
# │   ├── University of Ljubljana (id: Q1377, occurrences: 33)
# │   ├── Apple Inc. (id: Q312, occurrences: 22)
# │   └── Airbus (id: Q67, occurrences: 21)
# ├── Other (Showing top 5 of 1324)
# │   ├── English Wikipedia (id: Q328, occurrences: 47)
# │   ├── Havel (id: Q1682, occurrences: 47)
# │   ├── digital dark age (id: Q325, occurrences: 46)
# │   ├── Dresden (id: Q1731, occurrences: 45)
# │   ├── Padua (id: Q617, occurrences: 45)
# │   └── ...
# ├── Person (Showing top 5 of 394)
# │   ├── Meryl Streep (id: Q873, occurrences: 47)
# │   ├── Larry Sanger (id: Q185, occurrences: 45)
# │   ├── José Rizal (id: Q1500, occurrences: 44)
# │   ├── Leonel Manzano (id: Q1668, occurrences: 44)
# │   ├── Virgil (id: Q1398, occurrences: 42)
# │   └── ...
# └── Written Work (Showing top 5 of 3)
#     ├── Encyclopédie (id: Q447, occurrences: 28)
#     ├── Natural History (id: Q442, occurrences: 27)
#     └── Encyclopædia Britannica (id: Q455, occurrences: 23)
# '**Explanation of Changes:**\n*   **`MAX_LEAVES_PER_BRANCH`**: A variable is introduced to easily control how many entities you want to see per category.\n*   **Slicing**: The loop `for entity_data in entity_nodes_data[:MAX_LEAVES_PER_BRANCH]:` now uses list slicing to only iterate over the first 5 items.\n*   **Context in Node Name**: The category node now tells you how many total entities it contains (e.g., "Person (Showing top 5 of 127)").\n*   **Ellipsis Node**: An "..." node is added at the end of each branch if there were more entities than were displayed, clearly indicating that the view is truncated.'

# %%
# @title Ontology Restructuring and Refinement

import json
import time
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from tqdm.auto import tqdm
import os
from anytree import Node, RenderTree

# --- 0. Setup and Configuration ---
print("--- Step 0: Initializing ---")
PROJECT_ROOT = "/content/drive/MyDrive/ontology_project"
LINKED_ENTITIES_PATH = os.path.join(PROJECT_ROOT, "output/linked_entities.parquet")
CACHE_FILE = os.path.join(PROJECT_ROOT, "output/wikidata_cache.json")
NEW_ONTOLOGY_PATH = os.path.join(PROJECT_ROOT, "output/final_ontology_restructured.json")
MAX_LEAVES_PER_BRANCH = 7 # How many entities to show per category in the visualization

# --- 1. Re-use Existing Functions (for self-containment) ---

def get_wikidata_details_cached(wikidata_ids: list[str]):
    """Queries Wikidata using the existing cache to enrich our data."""
    try:
        with open(CACHE_FILE, 'r') as f: cache = json.load(f)
    except (IOError, json.JSONDecodeError):
        print("Warning: Wikidata cache not found. This run may be slow.")
        cache = {}

    ids_to_fetch = [qid for qid in wikidata_ids if qid not in cache]

    if ids_to_fetch:
        print(f"Cache miss for {len(ids_to_fetch)} IDs. Querying Wikidata...")
        sparql = SPARQLWrapper("https://query.wikidata.org/sparql", agent="ColabOntologyBuilder/1.0 (https://colab.research.google.com/)")
        chunk_size = 100
        for i in tqdm(range(0, len(ids_to_fetch), chunk_size), desc="Querying Wikidata"):
            id_chunk = ids_to_fetch[i:i+chunk_size]
            query = f"""
            SELECT ?item ?itemLabel ?itemDescription (GROUP_CONCAT(DISTINCT ?type; separator=",") AS ?types)
            WHERE {{
              VALUES ?item {{wd:{' wd:'.join(id_chunk)}}}
              OPTIONAL {{ ?item wdt:P31 ?type. }}
              SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
            }} GROUP BY ?item ?itemLabel ?itemDescription
            """
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)
            try:
                results = sparql.query().convert()
                for result in results["results"]["bindings"]:
                    qid = result['item']['value'].split('/')[-1]
                    cache[qid] = {'label': result.get('itemLabel', {}).get('value', 'N/A'), 'description': result.get('itemDescription', {}).get('value', 'N/A'), 'types': [t.split('/')[-1] for t in result.get('types', {}).get('value', '').split(',') if t]}
            except Exception as e: print(f"Error querying chunk: {e}")
            time.sleep(1)
        with open(CACHE_FILE, 'w') as f: json.dump(cache, f, indent=2)
    return {qid: cache.get(qid, {}) for qid in wikidata_ids}

# --- 2. Load and Aggregate the Original Data ---
print("\n--- Step 1: Loading and Aggregating Original Data ---")
try:
    df_links = pd.read_parquet(LINKED_ENTITIES_PATH)
except FileNotFoundError:
    print(f"ERROR: Could not find {LINKED_ENTITIES_PATH}")
    print("Please ensure you have successfully run Phase 3.")
    raise

df_aggregated = df_links.groupby('wikidata_id').agg(
    occurrences=('wikidata_id', 'count'),
    avg_confidence=('confidence', 'mean')
).reset_index()

print(f"Loaded and aggregated {len(df_aggregated)} unique entities.")

# --- 3. Enrich with Wikidata Types using the Cache ---
print("\n--- Step 2: Enriching Entities with Wikidata Types ---")
unique_ids = df_aggregated['wikidata_id'].tolist()
enriched_data = get_wikidata_details_cached(unique_ids)

df_aggregated['label'] = df_aggregated['wikidata_id'].apply(lambda qid: enriched_data.get(qid, {}).get('label', 'N/A'))
df_aggregated['description'] = df_aggregated['wikidata_id'].apply(lambda qid: enriched_data.get(qid, {}).get('description', 'N/A'))
df_aggregated['types'] = df_aggregated['wikidata_id'].apply(lambda qid: enriched_data.get(qid, {}).get('types', []))

print("Enrichment complete.")

# --- 4. Define New, Restructured Mapping Logic ---
print("\n--- Step 3: Defining and Applying New Restructuring Rules ---")

# This map defines our new, merged categories.
# The keys are the final category names.
# The values are lists of Wikidata Q-IDs that should be mapped to that category.
RESTRUCTURED_TYPE_MAP = {
    "Locations": [
        'Q515', 'Q6256', 'Q3957', 'Q1549591', 'Q5119', 'Q1286', 'Q1653',
        'Q82794', 'Q13221722', 'Q15284', 'Q486972', 'Q23442', 'Q98', 'Q97'
    ],
    "Organizations": [
        'Q43229', 'Q4830453', 'Q66', 'Q79913', 'Q1377', 'Q1003', 'Q1065'
    ],
    "Person": ['Q5'],
    # We will explicitly move Film and Written Work to "Other"
    "To_Other": ['Q11424', 'Q47461344']
}

def map_restructured_entity_type(types_list):
    """
    Applies the new mapping and merging rules.
    1. Checks for types to explicitly move to "Other".
    2. Checks for matches in Locations, Organizations, Person.
    3. Defaults to "Other" if no match is found.
    """
    if not types_list:
        return "Other"

    # Rule 1: Move specific types to Other
    if any(t in RESTRUCTURED_TYPE_MAP["To_Other"] for t in types_list):
        return "Other"

    # Rule 2: Check for a match in our main categories
    for category, qids in RESTRUCTURED_TYPE_MAP.items():
        if category == "To_Other": continue
        if any(t in qids for t in types_list):
            return category

    return "Other"

# Apply the new mapping function
df_aggregated['entity_type'] = df_aggregated['types'].apply(map_restructured_entity_type)
print("New category mapping applied.")
print("\nValue counts for new categories:")
print(df_aggregated['entity_type'].value_counts())

# --- 5. Build and Save the New Ontology ---
print("\n--- Step 4: Building and Saving Restructured Ontology ---")

def build_ontology_json(df_enriched):
    """Builds the final nested JSON ontology from the enriched DataFrame."""
    ontology = {"ontology": {"id": "root", "name": "Domain", "children": []}}
    # Sort by occurrences within each group to see the most frequent ones first
    df_enriched = df_enriched.sort_values(by="occurrences", ascending=False)
    grouped_by_type = df_enriched.groupby('entity_type')

    for type_name, group_df in grouped_by_type:
        type_node = {"id": f"concept_{type_name.lower()}", "name": type_name, "children": []}
        for _, row in group_df.iterrows():
            entity_node = {
                "id": row['wikidata_id'],
                "name": row['label'],
                "description": row['description'],
                "metadata": {
                    "occurrences": int(row['occurrences']),
                    "avg_confidence": round(float(row['avg_confidence']), 4)
                }
            }
            type_node['children'].append(entity_node)
        ontology['ontology']['children'].append(type_node)
    return ontology

final_ontology_restructured = build_ontology_json(df_aggregated)

with open(NEW_ONTOLOGY_PATH, 'w') as f:
    json.dump(final_ontology_restructured, f, indent=4)

print(f"New ontology saved to: {NEW_ONTOLOGY_PATH}")

# --- 6. Visualize the New, Pruned Tree ---
print(f"\n--- Pruned Restructured Tree (Top {MAX_LEAVES_PER_BRANCH} per Category) ---")
root_data = final_ontology_restructured.get('ontology', {})
root_node_pruned = Node(f"{root_data.get('name', 'Root')} (id: {root_data.get('id')})")
type_nodes_data = root_data.get('children', [])

for type_data in type_nodes_data:
    type_name = type_data.get('name', 'N/A')
    total_entities = len(type_data.get('children', []))
    type_node = Node(f"{type_name} (Showing top {min(MAX_LEAVES_PER_BRANCH, total_entities)} of {total_entities})", parent=root_node_pruned)

    for entity_data in type_data.get('children', [])[:MAX_LEAVES_PER_BRANCH]:
        name = entity_data.get('name', 'N/A')
        occurrences = entity_data.get('metadata', {}).get('occurrences', 0)
        Node(f"{name} (occurrences: {occurrences})", parent=type_node)

    if total_entities > MAX_LEAVES_PER_BRANCH:
        Node("...", parent=type_node)

for pre, _, node in RenderTree(root_node_pruned):
    print(f"{pre}{node.name}")
# Out:
# --- Step 0: Initializing ---
#
# --- Step 1: Loading and Aggregating Original Data ---
# Loaded and aggregated 1999 unique entities.
#
# --- Step 2: Enriching Entities with Wikidata Types ---
# Enrichment complete.
#
# --- Step 3: Defining and Applying New Restructuring Rules ---
# New category mapping applied.
#
# Value counts for new categories:
# entity_type
# Other            1222
# Person            394
# Locations         371
# Organizations      12
# Name: count, dtype: int64
#
# --- Step 4: Building and Saving Restructured Ontology ---
# New ontology saved to: /content/drive/MyDrive/ontology_project/output/final_ontology_restructured.json
#
# --- Pruned Restructured Tree (Top 7 per Category) ---
# Domain (id: root)
# ├── Locations (Showing top 7 of 371)
# │   ├── Bonn (occurrences: 49)
# │   ├── Dresden (occurrences: 45)
# │   ├── Padua (occurrences: 45)
# │   ├── La Paz (occurrences: 44)
# │   ├── Sri Lanka (occurrences: 43)
# │   ├── Bordeaux (occurrences: 42)
# │   ├── Cairo (occurrences: 42)
# │   └── ...
# ├── Organizations (Showing top 7 of 12)
# │   ├── Mercedes-Benz Mobility Services (occurrences: 40)
# │   ├── Boeing (occurrences: 38)
# │   ├── Q1418 (occurrences: 35)
# │   ├── Solidarity (occurrences: 34)
# │   ├── University of Ljubljana (occurrences: 33)
# │   ├── Google (occurrences: 33)
# │   ├── TogliattiAzot (occurrences: 32)
# │   └── ...
# ├── Other (Showing top 7 of 1222)
# │   ├── English Wikipedia (occurrences: 47)
# │   ├── Havel (occurrences: 47)
# │   ├── digital dark age (occurrences: 46)
# │   ├── Nagaland (occurrences: 44)
# │   ├── St. Pauli (occurrences: 44)
# │   ├── star (occurrences: 43)
# │   ├── Elde (occurrences: 43)
# │   └── ...
# └── Person (Showing top 7 of 394)
#     ├── Meryl Streep (occurrences: 47)
#     ├── Larry Sanger (occurrences: 45)
#     ├── Leonel Manzano (occurrences: 44)
#     ├── José Rizal (occurrences: 44)
#     ├── Virgil (occurrences: 42)
#     ├── Molière (occurrences: 41)
#     ├── Louis Armstrong (occurrences: 40)
#     └── ...
